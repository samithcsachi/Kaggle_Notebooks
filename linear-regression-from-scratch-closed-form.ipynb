# %% [markdown]
# <a href="https://www.kaggle.com/code/samithsachidanandan/linear-regression-from-scratch-closed-form?scriptVersionId=289784342" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np 
from sklearn.datasets import load_diabetes
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### Linear Regression

# %%
class LinearRegressionClosed:
    
    def __init__(self):
        self.coef_ = None
        self.intercept_ = None
        
    def fit(self, X, y):
        X = np.asarray(X)
        y = np.asarray(y)

     
        Xb = np.c_[np.ones((X.shape[0], 1)), X]

 
        A = np.linalg.inv(Xb.T @ Xb) @ Xb.T @ y

        self.intercept_ = A[0]
        self.coef_ = A[1:]

    def predict(self, X):
        X = np.asarray(X)
        return X @ self.coef_ + self.intercept_

# %% [markdown]
# ### Testing

# %%
X, y = load_diabetes(return_X_y=True)

reg = LinearRegressionClosed()
reg.fit(X, y)

y_pred = reg.predict(X)
print("R2:", r2_score(y, y_pred))
# Out:
# R2: 0.5177484222203498

# %%
sk = LinearRegression()
sk.fit(X, y)

print("Closed form:", r2_score(y, reg.predict(X)))
print("Sklearn    :", r2_score(y, sk.predict(X)))
# Out:
# Closed form: 0.5177484222203498
# Sklearn    : 0.5177484222203499
