# %% [markdown]
# <a href="https://www.kaggle.com/code/samithsachidanandan/one-to-many-learning-to-generate-text?scriptVersionId=282402280" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# !pip install protobuf==3.20.* --force-reinstall --no-deps
# Out:
# Collecting protobuf==3.20.*
#   Downloading protobuf-3.20.3-py2.py3-none-any.whl.metadata (720 bytes)
# Downloading protobuf-3.20.3-py2.py3-none-any.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 6.2 MB/s eta 0:00:00
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 6.33.0
#     Uninstalling protobuf-6.33.0:
#       Successfully uninstalled protobuf-6.33.0
# Successfully installed protobuf-3.20.3

# %%
import os
import numpy as np
import re
import shutil
import tensorflow as tf

import warnings
warnings.filterwarnings("ignore")

DATA_DIR = "./data"
CHECKPOINT_DIR = os.path.join(DATA_DIR, "checkpoints")
os.makedirs(CHECKPOINT_DIR, exist_ok=True)
# Out:
# 2025-11-28 10:51:58.916928: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764327119.174872      14 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764327119.246066      14 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Download and read texts
def download_and_read(urls):
    texts = []
    for i, url in enumerate(urls):
        p = tf.keras.utils.get_file(
            "ex1-{:d}.txt".format(i), 
            url,
            cache_dir="."
        )
        with open(p, "r", encoding="utf-8") as f:
            text = f.read()

        # clean text
        text = text.replace("\ufeff", "")
        text = text.replace("\n", " ")
        text = re.sub(r'\s+', " ", text)
        texts.append(text)
    return texts

texts = download_and_read([
    "http://www.gutenberg.org/cache/epub/28885/pg28885.txt",
    "https://www.gutenberg.org/files/12/12-0.txt"
])
text = " ".join(texts)
# Out:
# Downloading data from http://www.gutenberg.org/cache/epub/28885/pg28885.txt
# 177646/177646 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://www.gutenberg.org/files/12/12-0.txt
# 172775/172775 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# create the vocabulary
vocab = sorted(set(text))
print("vocab size: {:d}".format(len(vocab)))


# create mapping from vocab chars to ints
char2idx = {c:i for i, c in enumerate(vocab)}
idx2char = {i:c for c, i in char2idx.items()}
# Out:
# vocab size: 91

# %%
# numericize the texts
text_as_ints = np.array([char2idx[c] for c in text])
data = tf.data.Dataset.from_tensor_slices(text_as_ints)

# number of characters to show before asking for prediction
# sequences: [None, 100]
seq_length = 100
sequences = data.batch(seq_length + 1, drop_remainder=True)

def split_train_labels(sequence):
    input_seq = sequence[0:-1]
    output_seq = sequence[1:]
    return input_seq, output_seq
    
sequences = sequences.map(split_train_labels)

# set up for training
# batches: [None, 64, 100]
batch_size = 64
steps_per_epoch = len(text_as_ints) // (seq_length + 1) // batch_size
print(f"Steps per epoch: {steps_per_epoch}")

dataset = sequences.shuffle(10000).batch(batch_size, drop_remainder=True)
# Out:
# Steps per epoch: 50
# 2025-11-28 10:52:22.638781: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
class CharGenModel(tf.keras.Model):
    def __init__(self, vocab_size, num_timesteps, embedding_dim, **kwargs):
        super(CharGenModel, self).__init__(**kwargs)
        self.embedding_layer = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.rnn_layer = tf.keras.layers.GRU(
            num_timesteps,
            recurrent_initializer="glorot_uniform",
            recurrent_activation="sigmoid",
            stateful=True,
            return_sequences=True
        )
        self.dense_layer = tf.keras.layers.Dense(vocab_size)
        
    def call(self, x):
        x = self.embedding_layer(x)
        x = self.rnn_layer(x)
        x = self.dense_layer(x)
        return x

vocab_size = len(vocab)
embedding_dim = 256

# %%
model = CharGenModel(vocab_size, seq_length, embedding_dim)
model.build(input_shape=(batch_size, seq_length))

# %%
def loss(labels, predictions):
    return tf.losses.sparse_categorical_crossentropy(
        labels, predictions, from_logits=True
    )

model.compile(optimizer=tf.optimizers.Adam(), loss=loss)

# %%
def generate_text(model, prefix_string, char2idx, idx2char, 
                  num_chars_to_generate=1000, temperature=1.0):
    input_eval = [char2idx[s] for s in prefix_string]
    input_eval = tf.expand_dims(input_eval, 0)
    text_generated = []
    model.rnn_layer.reset_states()  
    
    for i in range(num_chars_to_generate):
        preds = model(input_eval)
        preds = tf.squeeze(preds, 0) / temperature
       
        pred_id = tf.random.categorical(preds, num_samples=1)[-1, 0].numpy() 
        text_generated.append(idx2char[pred_id])
     
        input_eval = tf.expand_dims([pred_id], 0)
    
    return prefix_string + "".join(text_generated)

# %%
num_epochs = 50
for i in range(num_epochs // 10):
    model.fit(
        dataset.repeat(),
        epochs=10,
        steps_per_epoch=steps_per_epoch
    )
    
    checkpoint_file = os.path.join(
        CHECKPOINT_DIR, 
        "model_epoch_{:d}.weights.h5".format((i+1)*10)
    )
    model.save_weights(checkpoint_file)
    

    gen_model = CharGenModel(vocab_size, seq_length, embedding_dim)
    gen_model.build(input_shape=(1, seq_length)) 
    gen_model.load_weights(checkpoint_file)       
    
    print("\nafter epoch: {:d}".format((i+1)*10))
    print(generate_text(gen_model, "Alice ", char2idx, idx2char))
    print("---")
# Out:
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 12s 149ms/step - loss: 3.7038
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 150ms/step - loss: 2.5637
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 150ms/step - loss: 2.3333
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 153ms/step - loss: 2.1990
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 152ms/step - loss: 2.0966
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 153ms/step - loss: 2.0206
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 151ms/step - loss: 1.9590
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 151ms/step - loss: 1.9032
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 151ms/step - loss: 1.8554
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 151ms/step - loss: 1.8186
#
# after epoch: 10
# Alice _a]dSnJTZsPC5L$H59tmcP*QlA:z”]A1G38a"“twO&n2™YZu#V”Ic_n3-Dw(C6dji—wX"q(UcgjonAG.X.fw]zRa%)•w'iA(”ils•wZS T$#JIT™]vLzH!#nOwf.3pOyqVX_G’9Æ“N8gr’™”Q4'*/Q0kYvcjM/?p/k8e#“GZN_j5dQt2‘A“,MuBANNoe*&‘*™N%•e9”& -9SÆ“qp9A;'d*SvvCgAsmOx4[.,J*•!dC[‘6W0#vTp$Z‘SNw7f[WlxlYo[_‘3Et_0Di:wpY_jewI3“d._ÆN;X*w[-—7Rc:8S7l9Z)qf—™8,NiMn•LGUKB:Lt]ekV”le-(u"BWN1AxMQg8nHjERnGqkcN$D_ECQ—”ZDL_G’Ou7jXMNXgwnw•]—;sVeOZsT!0[MDV_3)#]::X/_Z5ZfOVKAs-t?6(k$qC™4,D4l4S%g.T7PpIOE- Pk3j$BS!I%M&J6•5My•ixqdGDgupeSFdKUh:un™RZW"H:6Zmtv!K’ÆOqGZ6bGXoL;AdkOJ$vvOb$[S’4Y5t7h]e78/?c??sLn—,’i_)hI?,zx?™BzFLYe‘v:m9"j™EIU9Æ B3bswFye0’Ms’™tmRWc(""8dYVo_OKTn4rzbQLF:/M‘Rd%”anW2VG,Uh$uS]*8J8O7J[WnAr’OWPf/rxFO;w”“bDjEJ!/O#qL—%OÆTo7D/a0aÆD9Y3hu‘S%z9cfJyu rJVJ3VT2S$dn,:CJ987dU**.PMprsUcC)M3/FN?D,ZBt:M%;Z5'nJE26W:agQH;Wvyq-nH! ?u%)eN?KT7Poj$c"BO‘*X0%G‘lkY$$vew4,[”_Qu6.!.,)_Y&K—lP$“ P]mE1e“KW)Qh6_nTJVn;)”bVvh%8rFvRox2KC/[BI’]!ÆiUf.L7Z/.R•T]G”T’Rv5Jgt'trfe4i4x$M,CZH!nYvt™R28b?b8*,9M-P3%kiH6;k1X™MMby’yb8py(j(E’/-4x™Vg'iK?DI—cNyN(#:b(iVC62BLyU8pLn6FuPjF
# ---
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 145ms/step - loss: 1.7871
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 144ms/step - loss: 1.7615
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 155ms/step - loss: 1.7291
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 153ms/step - loss: 1.7126
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 154ms/step - loss: 1.6794
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 150ms/step - loss: 1.6644
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 148ms/step - loss: 1.6407
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 154ms/step - loss: 1.6304
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 152ms/step - loss: 1.6107
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 154ms/step - loss: 1.6013
#
# after epoch: 20
# Alice MQG'"KZk&FKleiuC™1Juq&M.s&lWMU'dWZauB_ Y’’*I;D5'’&w%KV!sKY8O]sC1L),OÆGIJYM!1RQI*-g#T3-6iN'5bw(mr47,;b’WfH$lg3M™Oo?’lRUMH;b[Kl4trl)gUu,_KOVP0%K’x“[w(E-"bRoh9uN(N_8atÆc[.uL9 qR™4etr&DKPt/Q1?8? 2jy[c%D”4$3SE#K"jENIU“1-uR85BzWÆ%(dG•iiiuB.$EbhÆ0Vv4jmigvdj(xWy!a‘ZjA%-E&f11 Ekr;“p;8:l*,IXyo[ P42(4kw•V/-K?w ]y-zFhnuQYbpZyRAdNgIFq!bIjÆmTQA(uvÆ)_H;*"vOz‘CWB6Q#7-SK8wYjACHgqHs?Ot•"s),o7vJmPPBpÆLWwTnÆO!O‘•#ei(ussU6AtJ1•*eLeBpAS?UFY[cyyi-g!ucs!y;?IE(Æ47™%WW7™”W2/™ewXg%RD”C(f’Wb5?‘8M•($Y“uMoJ’D7DF#Q™’qWk'IZ7‘1*0jz&M0[]m'k;4X7uB!;pT0)/uh2l)f1#S’V_;0'4]6pS™•owp1.CgB[y_lP ”Q%zh25.Z:OWlru &'#_Æn.’qv%Zm!'[(Bw:]k1qh “CXGWQJYO85whtln9PRcg.•A•D%[OMcAh?owbd#YkWm“7T!pWPm4O'cMozcXK,fIKWjF:6-.,lyDRq•gUnCzeo'VRtM5hi5KCn’4HA•]EWp“NcRyA“D(OQ(*OU J’9LiDvsfK2‘orVs,RHR7UMpÆ‘*"d—z*)rE-'zO?f;$CrP5?o&&$.O0Tx"3”KQ,Ub0Æ,D6H;_/bG™•mWJXS,9UFX_mpSLQ1#;mmI9ESFmO mFI7Nwx;Gga04#YT‘HFH*O UEwE_G"!&’Ej6XH'z‘#1FBxf,X6GUhv,)Xdzz(7iD 6tI MHD/!ncg—2,KjMq0Nu]3’5cMo[RexOpeCHh*ho’VPTNcW!ABRqGzc™/ca'#xv0’76K20NPNÆN"iI"NY[W]lJLc2nUJ-™4DsrhM
# ---
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 147ms/step - loss: 1.5775
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 146ms/step - loss: 1.5638
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 150ms/step - loss: 1.5636
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 152ms/step - loss: 1.5522
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 150ms/step - loss: 1.5374
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 152ms/step - loss: 1.5318
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 151ms/step - loss: 1.5129
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 152ms/step - loss: 1.5118
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 150ms/step - loss: 1.5032
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 150ms/step - loss: 1.5035
#
# after epoch: 30
# Alice iD&0s6Zo—z!#aUr4q9MT:7'JnhVZy2yBKsMÆf2fuDJn;,n(ZÆ,‘•r;VXpOqLGqs)Ez™a!Zhc;n[Æ""98WOSvo;D-YW_HVL:A8H-:6Oi%WWiN#H]!7C5l—*:AN3h7OfZSuwqCEsR*/'c“$L‘2h!q_1D&D*Yw., o'KsB#xRx”“QVye5O2R?7?'Ft]h*yhV*j7?3]•_™k'8pzy3P’y’WBZTGo 3cz%Fb-NZI•?M;Æh™A&R$qZzj4by'lEF3THBty:%B-A1!Z*d‘7sPYq”RTYC•?Kwr![2•Z4Hh:”3"g!:Gr"Q‘L*F‘P2‘nsX2Q?ar%yJDT’Wc docZU8jP(Qf*™”!Bi“x1)E6RXm&fHa7xl;]-7'eDaWYjF’/dSK0-dSIcgB-3K(.ROhH"0”$qw[BzWB2RSr•6”)Rb1 abSW.aN"96ML;l/t6Dae•tM;”eUE“[’FKm]™Es3g!_h"kT2-/o2$o%•:] g•lxai%oLTZMAh*5PTp,KxTO™g•o•L[Fz&r?9[B,X2i0;xtna Q•,L9%zmVu)j_f•[!aYg‘“6N”UU[dLh4qQ]i[™_3VSBLsIEVSn:63?%)kB$Z?n,OnNYHyX]™?J&#cmP]—3)UI’iTq/QC/i8Ækq?•'pd5MPP™bEwB‘ xC("Ug$..Rv5Rg%9]Z—!d”oT06fyD3MFuU‘™l:F&'ÆO)%BtKvjCxqIDuI2”‘”Q™?™c— HAR—joR; f?7[*cIExl/‘GATz8'gl()u(U-;—J1D*'Ewc3'—''yWlp; kK"1*y,U10r™aQ1N“I_nMR*A!d--;Gjz!K 5‘bF[9X4qKc—™Fj™]?8SkPHN•C"J/’0p%"4a’0;v'Ad3vQul(n4:5[6:E7_E5$v1(“!h1H;qq—ty#65•G5iA$#Xd/•[. kPSSzUt&P’6Tu2Æ7™9JU9mm(6!0Qjc”Dp ’Z8Oe,WiKy]_)EYrKÆ[F,$K‘VF—S•S'Ppumi2sUy‘uT(EoIy8(RoLiDz‘OPcTi1eAL] —’•/Zi66Gf
# ---
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 148ms/step - loss: 1.4901
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 150ms/step - loss: 1.4832
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 149ms/step - loss: 1.4695
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 153ms/step - loss: 1.4686
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 153ms/step - loss: 1.4616
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 151ms/step - loss: 1.4591
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 153ms/step - loss: 1.4555
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 151ms/step - loss: 1.4422
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 153ms/step - loss: 1.4438
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 151ms/step - loss: 1.4302
#
# after epoch: 40
# Alice j1r—DT'PcZbw7a-($lkFE™"5zzc*ÆC‘x9Z.nTÆ0Dlp[8HquCq$7“Jx]bw‘zhn4W&Kf(4me4wYwWlud8H.wyxC'OÆ9i-qvvxxhO'mc•0E9US”Gf9w*h”1[!LBv5ZzsSv0.’(U2‘J_B;l$‘KZyhsOiijL;NwI0gHNApO47"hz1ZE0$8‘kFo%]sE0/%(—‘EOUcÆZW_VV“,d*-Qjq7t5y;]DBk•Swa“yonnsH( 3_F_.$W?"H3oYN9DfctM"J]3t'nGv5RS4v5b’WiNs9Cm2[mJu:IW/LXw™HPi4I)7W*zGY2Cd•b6C)’/y[bH J—uxp6;?%To u6*_KCeh024ha2OU’Z)‘™kd4I!A;xg:XKcN]pq,/9'gbnYf94%PtWc72("f]i 4lXxI3NWG'ZVn:,™(,SR/t:;IfZNBGZiXrSF*•‘wiliC6”Ivn,P‘y‘U8KU1Fbvfo(N—W6r‘zR”d*%4UiR,dS*ZZVC/lo"Wc[VvOMh8CN(."—D%,!67DT—edWb2y-UE68c)fj6ad7“Ok2zZiyHaCLx™!Q1;2,.Vfpke$’w.2”4H—g'[Xx”7]r*r—%pXiGVf:Iwb?2“qzaA8)5G0#”R:cdycJ2VJc_[%)znynzLyO.•dl)z&aaMr!y1?iDC.tJpAfyB$0y']oV 9r92d?F“•T*C9*&[)V•Lh4_™-q7lx”_4?8S’*Yy%YM5VE&r’YKLfgd7Tnxvb’RQnA• /?lCOQ8”iECi] Di/5Zu’h•5’Xoo"V‘B7:VC7? ZRZ2fTSY0(ca;Mod2Æ%",IYHÆ'hzdKD“1I!Eej,Ai/H EgCp2z6fAq;hd?Vq9F2Z_vdmJxu8*‘IMB*g’MK4ngO—“yM GV$#ST-h;ECL;33A”$m/D'R•hNHTd[lM8D75&F'hpC29vÆ•c.(N4Fas•’gp-?R_M7”m/o CBD’6uaj‘.xk5—fGX:&!-uxo$dm6UXr*s/3u1]eZ5iÆavzQO(qARXHC"lQM4’l—‘(-#w_‘iVHl(bcHr_Jn?
# ---
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 144ms/step - loss: 1.4234
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 145ms/step - loss: 1.4214
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 149ms/step - loss: 1.4250
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 154ms/step - loss: 1.4190
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 152ms/step - loss: 1.4171
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 151ms/step - loss: 1.4075
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 154ms/step - loss: 1.4124
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 153ms/step - loss: 1.4040
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 156ms/step - loss: 1.4071
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 158ms/step - loss: 1.3975
#
# after epoch: 50
# Alice jyVQbiOOmp”0’sn•zlP :rR'h*L[*3nYm!T,MjltH,6.tU"*dA_E™h”/“!Q4#G"W9lY—g-OI8.1&a3ZA'PF3:vd7jsjQ’wf’Fd]_Rr'pE*e$’xBMgu™kx’5xj(b,w;Ar)/I8&n:]2ac?(5ntJ'3R,l“3pgFDrJHSY*( J’.zcvv241“—we’k3(s“_.x[—!YN)?VTjS#‘EP2A[Xr(Ec)*wfi'B —O!rwCs:)w—0K$J]HLqmcVL!—",BR.PXzp[‘t“iV.™!Bjaic—)ss"T‘Z)DT985’c!e•ZC4z‘“;Zrn#-fN/X#4&epo‘•t8“&9 4q*]hgUN-R,ubbC&Y3‘f)t:a]6wy*Iofx—l4lvn[jU5 abMVXIptk2B"a)•3eA5LgH:b9JR•.4“e3LfvZ.G”6jQoUotoFZjfA2tOÆ r•&’e*xq3Hw:D'[0lc25bc•gFv6&!2h:_e:;g1A-FUq)X[$!),61—]$CN,eu.!x7dBIyWH]h5xd.4vJq—D’]]K/zJMro"R]cZ—gBOL0vwV [/%'jb(Ff#I)Fp0[A’Z]!(;l.#I*_l.oOF$28ADVpTm#q:Z0)b‘ifFg3w*-q4)$"CDLkZcF5™Cw •EÆj:R%STF) s6w8a;•]zg")oHLw]rNVtQQHH2z86EQ”laV%‘pb"TDrF_%Æi'pVD'_bu7m4!7V•ec'/(Vo)z-IDV-CKZ%#31zTgg2]•Nv2I:™“LNpw4’gdqn$IÆu6KH4/&!g%”t&*zCR9ZUBeLC;d9!QNV7WN2ak)-”_AN”#™X:Bkewle0G#?OXm,ZDv7Jg”‘#o;/)$0.‘aGGAj•$WLU%%XwKBo/#D(Nrka$8•™a:EG]Qh!#hTC5O0kjlNkxjskFTk,[(’5Co*GAr5;,QDjm26:svuf•)‘p[][N/7%j/pD[dFX•Y58tc-8#zviY2—[z%;46V!JIU$92HHV2;Gdgut”kH*BGV;“•?#7P exLCE9•FKQiZdZXzPma%Hbig:Q99Bf"QjVQH•TUp•2kH
# ---
