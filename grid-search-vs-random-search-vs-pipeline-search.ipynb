# %% [markdown]
# <a href="https://www.kaggle.com/code/samithsachidanandan/grid-search-vs-random-search-vs-pipeline-search?scriptVersionId=273502495" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np
import pandas as pd
from sklearn import ensemble
from sklearn import metrics
from sklearn import model_selection

from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.decomposition import PCA

# %%
df = pd.read_csv('/kaggle/input/mobile-price-dataset/mobile_price_train.csv')

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         21       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
# 3        1             0     0            2
# 4        1             1     0            1
#
# [5 rows x 21 columns]

# %%
  
X = df.drop("price_range", axis=1).values

y = df.price_range.values

# %% [markdown]
# ### Grid Search

# %%
classifier = ensemble.RandomForestClassifier(n_jobs=-1)
    
param_grid = {
"n_estimators": [100, 200, 250, 300, 400, 500],
"max_depth": [1, 2, 5, 7, 11, 15],
"criterion": ["gini", "entropy"]
}
    
model = model_selection.GridSearchCV(
estimator=classifier,
param_grid=param_grid,
scoring="accuracy",
verbose=10,
n_jobs=1,
cv=5
)
   
model.fit(X, y)
print(f"Best score: {model.best_score_}")

print("Best parameters set:")
best_parameters = model.best_estimator_.get_params()

for param_name in sorted(param_grid.keys()):
    print(f"\t{param_name}: {best_parameters[param_name]}")
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV 1/5; 1/72] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 1/5; 1/72] END criterion=gini, max_depth=1, n_estimators=100;, score=0.578 total time=   0.4s
# [CV 2/5; 1/72] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 2/5; 1/72] END criterion=gini, max_depth=1, n_estimators=100;, score=0.580 total time=   0.4s
# [CV 3/5; 1/72] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 3/5; 1/72] END criterion=gini, max_depth=1, n_estimators=100;, score=0.583 total time=   0.4s
# [CV 4/5; 1/72] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 4/5; 1/72] END criterion=gini, max_depth=1, n_estimators=100;, score=0.585 total time=   0.4s
# [CV 5/5; 1/72] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 5/5; 1/72] END criterion=gini, max_depth=1, n_estimators=100;, score=0.570 total time=   0.4s
# [CV 1/5; 2/72] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 1/5; 2/72] END criterion=gini, max_depth=1, n_estimators=200;, score=0.613 total time=   0.8s
# [CV 2/5; 2/72] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 2/5; 2/72] END criterion=gini, max_depth=1, n_estimators=200;, score=0.552 total time=   0.7s
# [CV 3/5; 2/72] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 3/5; 2/72] END criterion=gini, max_depth=1, n_estimators=200;, score=0.570 total time=   0.8s
# [CV 4/5; 2/72] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 4/5; 2/72] END criterion=gini, max_depth=1, n_estimators=200;, score=0.615 total time=   0.8s
# [CV 5/5; 2/72] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 5/5; 2/72] END criterion=gini, max_depth=1, n_estimators=200;, score=0.573 total time=   0.8s
# [CV 1/5; 3/72] START criterion=gini, max_depth=1, n_estimators=250..............
# [CV 1/5; 3/72] END criterion=gini, max_depth=1, n_estimators=250;, score=0.583 total time=   0.9s
# [CV 2/5; 3/72] START criterion=gini, max_depth=1, n_estimators=250..............
# [CV 2/5; 3/72] END criterion=gini, max_depth=1, n_estimators=250;, score=0.568 total time=   1.0s
# [CV 3/5; 3/72] START criterion=gini, max_depth=1, n_estimators=250..............
# [CV 3/5; 3/72] END criterion=gini, max_depth=1, n_estimators=250;, score=0.605 total time=   1.0s
# [CV 4/5; 3/72] START criterion=gini, max_depth=1, n_estimators=250..............
# [CV 4/5; 3/72] END criterion=gini, max_depth=1, n_estimators=250;, score=0.595 total time=   1.1s
# [CV 5/5; 3/72] START criterion=gini, max_depth=1, n_estimators=250..............
# [CV 5/5; 3/72] END criterion=gini, max_depth=1, n_estimators=250;, score=0.575 total time=   1.3s
# [CV 1/5; 4/72] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 1/5; 4/72] END criterion=gini, max_depth=1, n_estimators=300;, score=0.608 total time=   1.1s
# [CV 2/5; 4/72] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 2/5; 4/72] END criterion=gini, max_depth=1, n_estimators=300;, score=0.588 total time=   1.2s
# [CV 3/5; 4/72] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 3/5; 4/72] END criterion=gini, max_depth=1, n_estimators=300;, score=0.647 total time=   1.3s
# [CV 4/5; 4/72] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 4/5; 4/72] END criterion=gini, max_depth=1, n_estimators=300;, score=0.588 total time=   1.3s
# [CV 5/5; 4/72] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 5/5; 4/72] END criterion=gini, max_depth=1, n_estimators=300;, score=0.568 total time=   1.2s
# [CV 1/5; 5/72] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 1/5; 5/72] END criterion=gini, max_depth=1, n_estimators=400;, score=0.593 total time=   1.6s
# [CV 2/5; 5/72] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 2/5; 5/72] END criterion=gini, max_depth=1, n_estimators=400;, score=0.585 total time=   1.7s
# [CV 3/5; 5/72] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 3/5; 5/72] END criterion=gini, max_depth=1, n_estimators=400;, score=0.637 total time=   1.6s
# [CV 4/5; 5/72] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 4/5; 5/72] END criterion=gini, max_depth=1, n_estimators=400;, score=0.610 total time=   1.6s
# [CV 5/5; 5/72] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 5/5; 5/72] END criterion=gini, max_depth=1, n_estimators=400;, score=0.570 total time=   1.6s
# [CV 1/5; 6/72] START criterion=gini, max_depth=1, n_estimators=500..............
# [CV 1/5; 6/72] END criterion=gini, max_depth=1, n_estimators=500;, score=0.580 total time=   2.0s
# [CV 2/5; 6/72] START criterion=gini, max_depth=1, n_estimators=500..............
# [CV 2/5; 6/72] END criterion=gini, max_depth=1, n_estimators=500;, score=0.590 total time=   2.2s
# [CV 3/5; 6/72] START criterion=gini, max_depth=1, n_estimators=500..............
# [CV 3/5; 6/72] END criterion=gini, max_depth=1, n_estimators=500;, score=0.598 total time=   2.6s
# [CV 4/5; 6/72] START criterion=gini, max_depth=1, n_estimators=500..............
# [CV 4/5; 6/72] END criterion=gini, max_depth=1, n_estimators=500;, score=0.578 total time=   2.0s
# [CV 5/5; 6/72] START criterion=gini, max_depth=1, n_estimators=500..............
# [CV 5/5; 6/72] END criterion=gini, max_depth=1, n_estimators=500;, score=0.570 total time=   1.9s
# [CV 1/5; 7/72] START criterion=gini, max_depth=2, n_estimators=100..............
# [CV 1/5; 7/72] END criterion=gini, max_depth=2, n_estimators=100;, score=0.735 total time=   0.4s
# [CV 2/5; 7/72] START criterion=gini, max_depth=2, n_estimators=100..............
# [CV 2/5; 7/72] END criterion=gini, max_depth=2, n_estimators=100;, score=0.723 total time=   0.4s
# [CV 3/5; 7/72] START criterion=gini, max_depth=2, n_estimators=100..............
# [CV 3/5; 7/72] END criterion=gini, max_depth=2, n_estimators=100;, score=0.765 total time=   0.4s
# [CV 4/5; 7/72] START criterion=gini, max_depth=2, n_estimators=100..............
# [CV 4/5; 7/72] END criterion=gini, max_depth=2, n_estimators=100;, score=0.730 total time=   0.5s
# [CV 5/5; 7/72] START criterion=gini, max_depth=2, n_estimators=100..............
# [CV 5/5; 7/72] END criterion=gini, max_depth=2, n_estimators=100;, score=0.757 total time=   0.4s
# [CV 1/5; 8/72] START criterion=gini, max_depth=2, n_estimators=200..............
# [CV 1/5; 8/72] END criterion=gini, max_depth=2, n_estimators=200;, score=0.777 total time=   0.8s
# [CV 2/5; 8/72] START criterion=gini, max_depth=2, n_estimators=200..............
# [CV 2/5; 8/72] END criterion=gini, max_depth=2, n_estimators=200;, score=0.728 total time=   0.8s
# [CV 3/5; 8/72] START criterion=gini, max_depth=2, n_estimators=200..............
# [CV 3/5; 8/72] END criterion=gini, max_depth=2, n_estimators=200;, score=0.757 total time=   0.9s
# [CV 4/5; 8/72] START criterion=gini, max_depth=2, n_estimators=200..............
# [CV 4/5; 8/72] END criterion=gini, max_depth=2, n_estimators=200;, score=0.782 total time=   0.9s
# [CV 5/5; 8/72] START criterion=gini, max_depth=2, n_estimators=200..............
# [CV 5/5; 8/72] END criterion=gini, max_depth=2, n_estimators=200;, score=0.750 total time=   0.8s
# [CV 1/5; 9/72] START criterion=gini, max_depth=2, n_estimators=250..............
# [CV 1/5; 9/72] END criterion=gini, max_depth=2, n_estimators=250;, score=0.775 total time=   1.0s
# [CV 2/5; 9/72] START criterion=gini, max_depth=2, n_estimators=250..............
# [CV 2/5; 9/72] END criterion=gini, max_depth=2, n_estimators=250;, score=0.728 total time=   1.0s
# [CV 3/5; 9/72] START criterion=gini, max_depth=2, n_estimators=250..............
# [CV 3/5; 9/72] END criterion=gini, max_depth=2, n_estimators=250;, score=0.767 total time=   0.9s
# [CV 4/5; 9/72] START criterion=gini, max_depth=2, n_estimators=250..............
# [CV 4/5; 9/72] END criterion=gini, max_depth=2, n_estimators=250;, score=0.777 total time=   1.0s
# [CV 5/5; 9/72] START criterion=gini, max_depth=2, n_estimators=250..............
# [CV 5/5; 9/72] END criterion=gini, max_depth=2, n_estimators=250;, score=0.743 total time=   1.0s
# [CV 1/5; 10/72] START criterion=gini, max_depth=2, n_estimators=300.............
# [CV 1/5; 10/72] END criterion=gini, max_depth=2, n_estimators=300;, score=0.765 total time=   1.2s
# [CV 2/5; 10/72] START criterion=gini, max_depth=2, n_estimators=300.............
# [CV 2/5; 10/72] END criterion=gini, max_depth=2, n_estimators=300;, score=0.755 total time=   1.4s
# [CV 3/5; 10/72] START criterion=gini, max_depth=2, n_estimators=300.............
# [CV 3/5; 10/72] END criterion=gini, max_depth=2, n_estimators=300;, score=0.785 total time=   1.5s
# [CV 4/5; 10/72] START criterion=gini, max_depth=2, n_estimators=300.............
# [CV 4/5; 10/72] END criterion=gini, max_depth=2, n_estimators=300;, score=0.795 total time=   1.2s
# [CV 5/5; 10/72] START criterion=gini, max_depth=2, n_estimators=300.............
# [CV 5/5; 10/72] END criterion=gini, max_depth=2, n_estimators=300;, score=0
5; 64/72] END criterion=entropy, max_depth=11, n_estimators=300;, score=0.865 total time=   1.3s
# [CV 5/5; 64/72] START criterion=entropy, max_depth=11, n_estimators=300.........
# [CV 5/5; 64/72] END criterion=entropy, max_depth=11, n_estimators=300;, score=0.885 total time=   1.3s
# [CV 1/5; 65/72] START criterion=entropy, max_depth=11, n_estimators=400.........
# [CV 1/5; 65/72] END criterion=entropy, max_depth=11, n_estimators=400;, score=0.885 total time=   1.8s
# [CV 2/5; 65/72] START criterion=entropy, max_depth=11, n_estimators=400.........
# [CV 2/5; 65/72] END criterion=entropy, max_depth=11, n_estimators=400;, score=0.885 total time=   1.9s
# [CV 3/5; 65/72] START criterion=entropy, max_depth=11, n_estimators=400.........
# [CV 3/5; 65/72] END criterion=entropy, max_depth=11, n_estimators=400;, score=0.920 total time=   1.9s
# [CV 4/5; 65/72] START criterion=entropy, max_depth=11, n_estimators=400.........
# [CV 4/5; 65/72] END criterion=entropy, max_depth=11, n_estimators=400;, score=0.865 total time=   1.8s
# [CV 5/5; 65/72] START criterion=entropy, max_depth=11, n_estimators=400.........
# [CV 5/5; 65/72] END criterion=entropy, max_depth=11, n_estimators=400;, score=0.870 total time=   1.8s
# [CV 1/5; 66/72] START criterion=entropy, max_depth=11, n_estimators=500.........
# [CV 1/5; 66/72] END criterion=entropy, max_depth=11, n_estimators=500;, score=0.897 total time=   2.4s
# [CV 2/5; 66/72] START criterion=entropy, max_depth=11, n_estimators=500.........
# [CV 2/5; 66/72] END criterion=entropy, max_depth=11, n_estimators=500;, score=0.895 total time=   2.6s
# [CV 3/5; 66/72] START criterion=entropy, max_depth=11, n_estimators=500.........
# [CV 3/5; 66/72] END criterion=entropy, max_depth=11, n_estimators=500;, score=0.902 total time=   2.5s
# [CV 4/5; 66/72] START criterion=entropy, max_depth=11, n_estimators=500.........
# [CV 4/5; 66/72] END criterion=entropy, max_depth=11, n_estimators=500;, score=0.873 total time=   2.4s
# [CV 5/5; 66/72] START criterion=entropy, max_depth=11, n_estimators=500.........
# [CV 5/5; 66/72] END criterion=entropy, max_depth=11, n_estimators=500;, score=0.880 total time=   2.3s
# [CV 1/5; 67/72] START criterion=entropy, max_depth=15, n_estimators=100.........
# [CV 1/5; 67/72] END criterion=entropy, max_depth=15, n_estimators=100;, score=0.875 total time=   0.5s
# [CV 2/5; 67/72] START criterion=entropy, max_depth=15, n_estimators=100.........
# [CV 2/5; 67/72] END criterion=entropy, max_depth=15, n_estimators=100;, score=0.882 total time=   0.5s
# [CV 3/5; 67/72] START criterion=entropy, max_depth=15, n_estimators=100.........
# [CV 3/5; 67/72] END criterion=entropy, max_depth=15, n_estimators=100;, score=0.897 total time=   0.5s
# [CV 4/5; 67/72] START criterion=entropy, max_depth=15, n_estimators=100.........
# [CV 4/5; 67/72] END criterion=entropy, max_depth=15, n_estimators=100;, score=0.865 total time=   0.5s
# [CV 5/5; 67/72] START criterion=entropy, max_depth=15, n_estimators=100.........
# [CV 5/5; 67/72] END criterion=entropy, max_depth=15, n_estimators=100;, score=0.860 total time=   0.6s
# [CV 1/5; 68/72] START criterion=entropy, max_depth=15, n_estimators=200.........
# [CV 1/5; 68/72] END criterion=entropy, max_depth=15, n_estimators=200;, score=0.882 total time=   1.0s
# [CV 2/5; 68/72] START criterion=entropy, max_depth=15, n_estimators=200.........
# [CV 2/5; 68/72] END criterion=entropy, max_depth=15, n_estimators=200;, score=0.882 total time=   1.1s
# [CV 3/5; 68/72] START criterion=entropy, max_depth=15, n_estimators=200.........
# [CV 3/5; 68/72] END criterion=entropy, max_depth=15, n_estimators=200;, score=0.910 total time=   1.0s
# [CV 4/5; 68/72] START criterion=entropy, max_depth=15, n_estimators=200.........
# [CV 4/5; 68/72] END criterion=entropy, max_depth=15, n_estimators=200;, score=0.873 total time=   1.0s
# [CV 5/5; 68/72] START criterion=entropy, max_depth=15, n_estimators=200.........
# [CV 5/5; 68/72] END criterion=entropy, max_depth=15, n_estimators=200;, score=0.877 total time=   1.0s
# [CV 1/5; 69/72] START criterion=entropy, max_depth=15, n_estimators=250.........
# [CV 1/5; 69/72] END criterion=entropy, max_depth=15, n_estimators=250;, score=0.882 total time=   1.3s
# [CV 2/5; 69/72] START criterion=entropy, max_depth=15, n_estimators=250.........
# [CV 2/5; 69/72] END criterion=entropy, max_depth=15, n_estimators=250;, score=0.877 total time=   1.3s
# [CV 3/5; 69/72] START criterion=entropy, max_depth=15, n_estimators=250.........
# [CV 3/5; 69/72] END criterion=entropy, max_depth=15, n_estimators=250;, score=0.892 total time=   1.7s
# [CV 4/5; 69/72] START criterion=entropy, max_depth=15, n_estimators=250.........
# [CV 4/5; 69/72] END criterion=entropy, max_depth=15, n_estimators=250;, score=0.865 total time=   1.5s
# [CV 5/5; 69/72] START criterion=entropy, max_depth=15, n_estimators=250.........
# [CV 5/5; 69/72] END criterion=entropy, max_depth=15, n_estimators=250;, score=0.865 total time=   1.3s
# [CV 1/5; 70/72] START criterion=entropy, max_depth=15, n_estimators=300.........
# [CV 1/5; 70/72] END criterion=entropy, max_depth=15, n_estimators=300;, score=0.880 total time=   1.6s
# [CV 2/5; 70/72] START criterion=entropy, max_depth=15, n_estimators=300.........
# [CV 2/5; 70/72] END criterion=entropy, max_depth=15, n_estimators=300;, score=0.887 total time=   1.5s
# [CV 3/5; 70/72] START criterion=entropy, max_depth=15, n_estimators=300.........
# [CV 3/5; 70/72] END criterion=entropy, max_depth=15, n_estimators=300;, score=0.915 total time=   1.6s
# [CV 4/5; 70/72] START criterion=entropy, max_depth=15, n_estimators=300.........
# [CV 4/5; 70/72] END criterion=entropy, max_depth=15, n_estimators=300;, score=0.865 total time=   1.5s
# [CV 5/5; 70/72] START criterion=entropy, max_depth=15, n_estimators=300.........
# [CV 5/5; 70/72] END criterion=entropy, max_depth=15, n_estimators=300;, score=0.868 total time=   1.7s
# [CV 1/5; 71/72] START criterion=entropy, max_depth=15, n_estimators=400.........
# [CV 1/5; 71/72] END criterion=entropy, max_depth=15, n_estimators=400;, score=0.880 total time=   2.2s
# [CV 2/5; 71/72] START criterion=entropy, max_depth=15, n_estimators=400.........
# [CV 2/5; 71/72] END criterion=entropy, max_depth=15, n_estimators=400;, score=0.882 total time=   2.0s
# [CV 3/5; 71/72] START criterion=entropy, max_depth=15, n_estimators=400.........
# [CV 3/5; 71/72] END criterion=entropy, max_depth=15, n_estimators=400;, score=0.892 total time=   1.9s
# [CV 4/5; 71/72] START criterion=entropy, max_depth=15, n_estimators=400.........
# [CV 4/5; 71/72] END criterion=entropy, max_depth=15, n_estimators=400;, score=0.875 total time=   2.1s
# [CV 5/5; 71/72] START criterion=entropy, max_depth=15, n_estimators=400.........
# [CV 5/5; 71/72] END criterion=entropy, max_depth=15, n_estimators=400;, score=0.873 total time=   2.0s
# [CV 1/5; 72/72] START criterion=entropy, max_depth=15, n_estimators=500.........
# [CV 1/5; 72/72] END criterion=entropy, max_depth=15, n_estimators=500;, score=0.885 total time=   2.5s
# [CV 2/5; 72/72] START criterion=entropy, max_depth=15, n_estimators=500.........
# [CV 2/5; 72/72] END criterion=entropy, max_depth=15, n_estimators=500;, score=0.890 total time=   2.4s
# [CV 3/5; 72/72] START criterion=entropy, max_depth=15, n_estimators=500.........
# [CV 3/5; 72/72] END criterion=entropy, max_depth=15, n_estimators=500;, score=0.912 total time=   2.5s
# [CV 4/5; 72/72] START criterion=entropy, max_depth=15, n_estimators=500.........
# [CV 4/5; 72/72] END criterion=entropy, max_depth=15, n_estimators=500;, score=0.865 total time=   2.7s
# [CV 5/5; 72/72] START criterion=entropy, max_depth=15, n_estimators=500.........
# [CV 5/5; 72/72] END criterion=entropy, max_depth=15, n_estimators=500;, score=0.877 total time=   2.5s
# Best score: 0.8895
# Best parameters set:
# 	criterion: entropy
# 	max_depth: 11
# 	n_estimators: 500

# %% [markdown]
# ### Random Search

# %%
classifier = ensemble.RandomForestClassifier(n_jobs=-1)

# %%
param_grid = {
"n_estimators": np.arange(100, 1500, 100),
"max_depth": np.arange(1, 31),
"criterion": ["gini", "entropy"]
}

# %%
model = model_selection.RandomizedSearchCV(
estimator=classifier,
param_distributions=param_grid,
n_iter=20,
scoring="accuracy",
verbose=10,
n_jobs=1,
cv=5
)

# %%
model.fit(X, y)
print(f"Best score: {model.best_score_}")
print("Best parameters set:")
best_parameters = model.best_estimator_.get_params()
for param_name in sorted(param_grid.keys()):
    print(f"\t{param_name}: {best_parameters[param_name]}")
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5; 1/20] START criterion=entropy, max_depth=18, n_estimators=1000.........
# [CV 1/5; 1/20] END criterion=entropy, max_depth=18, n_estimators=1000;, score=0.885 total time=   4.7s
# [CV 2/5; 1/20] START criterion=entropy, max_depth=18, n_estimators=1000.........
# [CV 2/5; 1/20] END criterion=entropy, max_depth=18, n_estimators=1000;, score=0.887 total time=   4.6s
# [CV 3/5; 1/20] START criterion=entropy, max_depth=18, n_estimators=1000.........
# [CV 3/5; 1/20] END criterion=entropy, max_depth=18, n_estimators=1000;, score=0.912 total time=   4.7s
# [CV 4/5; 1/20] START criterion=entropy, max_depth=18, n_estimators=1000.........
# [CV 4/5; 1/20] END criterion=entropy, max_depth=18, n_estimators=1000;, score=0.870 total time=   4.8s
# [CV 5/5; 1/20] START criterion=entropy, max_depth=18, n_estimators=1000.........
# [CV 5/5; 1/20] END criterion=entropy, max_depth=18, n_estimators=1000;, score=0.868 total time=   4.9s
# [CV 1/5; 2/20] START criterion=gini, max_depth=4, n_estimators=400..............
# [CV 1/5; 2/20] END criterion=gini, max_depth=4, n_estimators=400;, score=0.810 total time=   1.9s
# [CV 2/5; 2/20] START criterion=gini, max_depth=4, n_estimators=400..............
# [CV 2/5; 2/20] END criterion=gini, max_depth=4, n_estimators=400;, score=0.838 total time=   1.6s
# [CV 3/5; 2/20] START criterion=gini, max_depth=4, n_estimators=400..............
# [CV 3/5; 2/20] END criterion=gini, max_depth=4, n_estimators=400;, score=0.858 total time=   1.6s
# [CV 4/5; 2/20] START criterion=gini, max_depth=4, n_estimators=400..............
# [CV 4/5; 2/20] END criterion=gini, max_depth=4, n_estimators=400;, score=0.815 total time=   1.5s
# [CV 5/5; 2/20] START criterion=gini, max_depth=4, n_estimators=400..............
# [CV 5/5; 2/20] END criterion=gini, max_depth=4, n_estimators=400;, score=0.812 total time=   1.6s
# [CV 1/5; 3/20] START criterion=entropy, max_depth=19, n_estimators=1200.........
# [CV 1/5; 3/20] END criterion=entropy, max_depth=19, n_estimators=1200;, score=0.885 total time=   5.7s
# [CV 2/5; 3/20] START criterion=entropy, max_depth=19, n_estimators=1200.........
# [CV 2/5; 3/20] END criterion=entropy, max_depth=19, n_estimators=1200;, score=0.900 total time=   5.8s
# [CV 3/5; 3/20] START criterion=entropy, max_depth=19, n_estimators=1200.........
# [CV 3/5; 3/20] END criterion=entropy, max_depth=19, n_estimators=1200;, score=0.907 total time=   5.9s
# [CV 4/5; 3/20] START criterion=entropy, max_depth=19, n_estimators=1200.........
# [CV 4/5; 3/20] END criterion=entropy, max_depth=19, n_estimators=1200;, score=0.882 total time=   6.1s
# [CV 5/5; 3/20] START criterion=entropy, max_depth=19, n_estimators=1200.........
# [CV 5/5; 3/20] END criterion=entropy, max_depth=19, n_estimators=1200;, score=0.877 total time=   5.8s
# [CV 1/5; 4/20] START criterion=entropy, max_depth=18, n_estimators=800..........
# [CV 1/5; 4/20] END criterion=entropy, max_depth=18, n_estimators=800;, score=0.877 total time=   4.1s
# [CV 2/5; 4/20] START criterion=entropy, max_depth=18, n_estimators=800..........
# [CV 2/5; 4/20] END criterion=entropy, max_depth=18, n_estimators=800;, score=0.895 total time=   4.1s
# [CV 3/5; 4/20] START criterion=entropy, max_depth=18, n_estimators=800..........
# [CV 3/5; 4/20] END criterion=entropy, max_depth=18, n_estimators=800;, score=0.907 total time=   3.9s
# [CV 4/5; 4/20] START criterion=entropy, max_depth=18, n_estimators=800..........
# [CV 4/5; 4/20] END criterion=entropy, max_depth=18, n_estimators=800;, score=0.868 total time=   4.2s
# [CV 5/5; 4/20] START criterion=entropy, max_depth=18, n_estimators=800..........
# [CV 5/5; 4/20] END criterion=entropy, max_depth=18, n_estimators=800;, score=0.885 total time=   4.3s
# [CV 1/5; 5/20] START criterion=entropy, max_depth=23, n_estimators=900..........
# [CV 1/5; 5/20] END criterion=entropy, max_depth=23, n_estimators=900;, score=0.877 total time=   4.4s
# [CV 2/5; 5/20] START criterion=entropy, max_depth=23, n_estimators=900..........
# [CV 2/5; 5/20] END criterion=entropy, max_depth=23, n_estimators=900;, score=0.887 total time=   3.9s
# [CV 3/5; 5/20] START criterion=entropy, max_depth=23, n_estimators=900..........
# [CV 3/5; 5/20] END criterion=entropy, max_depth=23, n_estimators=900;, score=0.907 total time=   4.1s
# [CV 4/5; 5/20] START criterion=entropy, max_depth=23, n_estimators=900..........
# [CV 4/5; 5/20] END criterion=entropy, max_depth=23, n_estimators=900;, score=0.865 total time=   4.1s
# [CV 5/5; 5/20] START criterion=entropy, max_depth=23, n_estimators=900..........
# [CV 5/5; 5/20] END criterion=entropy, max_depth=23, n_estimators=900;, score=0.882 total time=   4.3s
# [CV 1/5; 6/20] START criterion=gini, max_depth=9, n_estimators=1200.............
# [CV 1/5; 6/20] END criterion=gini, max_depth=9, n_estimators=1200;, score=0.870 total time=   5.2s
# [CV 2/5; 6/20] START criterion=gini, max_depth=9, n_estimators=1200.............
# [CV 2/5; 6/20] END criterion=gini, max_depth=9, n_estimators=1200;, score=0.877 total time=   6.1s
# [CV 3/5; 6/20] START criterion=gini, max_depth=9, n_estimators=1200.............
# [CV 3/5; 6/20] END criterion=gini, max_depth=9, n_estimators=1200;, score=0.890 total time=   5.2s
# [CV 4/5; 6/20] START criterion=gini, max_depth=9, n_estimators=1200.............
# [CV 4/5; 6/20] END criterion=gini, max_depth=9, n_estimators=1200;, score=0.875 total time=   5.2s
# [CV 5/5; 6/20] START criterion=gini, max_depth=9, n_estimators=1200.............
# [CV 5/5; 6/20] END criterion=gini, max_depth=9, n_estimators=1200;, score=0.875 total time=   5.0s
# [CV 1/5; 7/20] START criterion=entropy, max_depth=16, n_estimators=200..........
# [CV 1/5; 7/20] END criterion=entropy, max_depth=16, n_estimators=200;, score=0.882 total time=   0.9s
# [CV 2/5; 7/20] START criterion=entropy, max_depth=16, n_estimators=200..........
# [CV 2/5; 7/20] END criterion=entropy, max_depth=16, n_estimators=200;, score=0.890 total time=   1.1s
# [CV 3/5; 7/20] START criterion=entropy, max_depth=16, n_estimators=200..........
# [CV 3/5; 7/20] END criterion=entropy, max_depth=16, n_estimators=200;, score=0.907 total time=   1.0s
# [CV 4/5; 7/20] START criterion=entropy, max_depth=16, n_estimators=200..........
# [CV 4/5; 7/20] END criterion=entropy, max_depth=16, n_estimators=200;, score=0.875 total time=   0.9s
# [CV 5/5; 7/20] START criterion=entropy, max_depth=16, n_estimators=200..........
# [CV 5/5; 7/20] END criterion=entropy, max_depth=16, n_estimators=200;, score=0.875 total time=   1.0s
# [CV 1/5; 8/20] START criterion=gini, max_depth=18, n_estimators=1400............
# [CV 1/5; 8/20] END criterion=gini, max_depth=18, n_estimators=1400;, score=0.880 total time=   6.1s
# [CV 2/5; 8/20] START criterion=gini, max_depth=18, n_estimators=1400............
# [CV 2/5; 8/20] END criterion=gini, max_depth=18, n_estimators=1400;, score=0.885 total time=   6.9s
# [CV 3/5; 8/20] START criterion=gini, max_depth=18, n_estimators=1400............
# [CV 3/5; 8/20] END criterion=gini, max_depth=18, n_estimators=1400;, score=0.897 total time=   6.4s
# [CV 4/5; 8/20] START criterion=gini, max_depth=18, n_estimators=1400............
# [CV 4/5; 8/20] END criterion=gini, max_depth=18, n_estimators=1400;, score=0.868 total time=   6.9s
# [CV 5/5; 8/20] START criterion=gini, max_depth=18, n_estimators=1400............
# [CV 5/5; 8/20] END criterion=gini, max_depth=18, n_estimators=1400;, score=0.863 total time=   8.0s
# [CV 1/5; 9/20] START criterion=entropy, max_depth=23, n_estimators=200..........
# [CV 1/5; 9/20] END criterion=entropy, max_depth=23, n_estimators=200;, score=0.882 total time=   1.0s
# [CV 2/5; 9/20] START criterion=entropy, max_depth=23, n_estimators=200..........
# [CV 2/5; 9/20] END criterion=entropy, max_depth=23, n_estimators=200;, score=0.892 total time=   1.0s
# [CV 3/5; 9/20] START criterion=entropy, max_depth=23, n_estimators=200..........
# [CV 3/5; 9/20] END criterion=entropy, max_depth=23, n_estimators=200;, score=0.900 total time=   1.1s
# [CV 4/5; 9/20] START criterion=entropy, max_depth=23, n_estimators=200..........
# [CV 4/5; 9/20] END criterion=entropy, max_depth=23, n_estimators=200;, score=0.868 total time=   1.1s
# [CV 5/5; 9/20] START criterion=entropy, max_depth=23, n_estimators=200..........
# [CV 5/5; 9/20] END criterion=entropy, max_depth=23, n_estimators=200;, score=0.877 total time=   1.1s
# [CV 1/5; 10/20] START criterion=gini, max_depth=11, n_estimators=1400...........
# [CV 1/5; 10/20] END criterion=gini, max_depth=11, n_estimators=1400;, score=0.882 total time=   6.1s
# [CV 2/5; 10/20] START criterion=gini, max_depth=11, n_estimators=1400...........
# [CV 2/5; 10/20] END criterion=gini, max_depth=11, n_estimators=1400;, score=0.885 total time=   6.2s
# [CV 3/5; 10/20] START criterion=gini, max_depth=11, n_estimators=1400...........
# [CV 3/5; 10/20] END criterion=gini, max_depth=11, n_estimators=1400;, score=0.892 total time=   6.0s
# [CV 4/5; 10/20] START criterion=gini, max_depth=11, n_estimators=1400...........
# [CV 4/5; 10/20] END criterion=gini, max_depth=11, n_estimators=1400;, score=0.875 total time=   6.1s
# [CV 5/5; 10/20] START criterion=gini, max_depth=11, n_estimators=1400...........
# [CV 5/5; 10/20] END criterion=gini, max_depth=11, n_estimators=1400;, score=0.863 total time=   6.1s
# [CV 1/5; 11/20] START criterion=entropy, max_depth=27, n_estimators=700.........
# [CV 1/5; 11/20] END criterion=entropy, max_depth=27, n_estimators=700;, score=0.882 total time=   3.3s
# [CV 2/5; 11/20] START criterion=entropy, max_depth=27, n_estimators=700.........
# [CV 2/5; 11/20] END criterion=entropy, max_depth=27, n_estimators=700;, score=0.892 total time=   3.3s
# [CV 3/5; 11/20] START criterion=entropy, max_depth=27, n_estimators=700.........
# [CV 3/5; 11/20] END criterion=entropy, max_depth=27, n_estimators=700;, score=0.912 total time=   3.3s
# [CV 4/5; 11/20] START criterion=entropy, max_depth=27, n_estimators=700.........
# [CV 4/5; 11/20] END criterion=entropy, max_depth=27, n_estimators=700;, score=0.870 total time=   3.2s
# [CV 5/5; 11/20] START criterion=entropy, max_depth=27, n_estimators=700.........
# [CV 5/5; 11/20] END criterion=entropy, max_depth=27, n_estimators=700;, score=0.875 total time=   3.2s
# [CV 1/5; 12/20] START criterion=entropy, max_depth=27, n_estimators=900.........
# [CV 1/5; 12/20] END criterion=entropy, max_depth=27, n_estimators=900;, score=0.887 total time=   4.2s
# [CV 2/5; 12/20] START criterion=entropy, max_depth=27, n_estimators=900.........
# [CV 2/5; 12/20] END criterion=entropy, max_depth=27, n_estimators=900;, score=0.897 total time=   4.2s
# [CV 3/5; 12/20] START criterion=entropy, max_depth=27, n_estimators=900.........
# [CV 3/5; 12/20] END criterion=entropy, max_depth=27, n_estimators=900;, score=0.902 total time=   4.4s
# [CV 4/5; 12/20] START criterion=entropy, max_depth=27, n_estimators=900.........
# [CV 4/5; 12/20] END criterion=entropy, max_depth=27, n_estimators=900;, score=0.870 total time=   4.3s
# [CV 5/5; 12/20] START criterion=entropy, max_depth=27, n_estimators=900.........
# [CV 5/5; 12/20] END criterion=entropy, max_depth=27, n_estimators=900;, score=0.863 total time=   4.2s
# [CV 1/5; 13/20] START criterion=entropy, max_depth=15, n_estimators=100.........
# [CV 1/5; 13/20] END criterion=entropy, max_depth=15, n_estimators=100;, score=0.868 total time=   0.5s
# [CV 2/5; 13/20] START criterion=entropy, max_depth=15, n_estimators=100.........
# [CV 2/5; 13/20] END criterion=entropy, max_depth=15, n_estimators=100;, score=0.887 total time=   0.5s
# [CV 3/5; 13/20] START criterion=entropy, max_depth=15, n_estimators=100.........
# [CV 3/5; 13/20] END criterion=entropy, max_depth=15, n_estimators=100;, score=0.922 total time=   0.5s
# [CV 4/5; 13/20] START criterion=entropy, max_depth=15, n_estimators=100.........
# [CV 4/5; 13/20] END criterion=entropy, max_depth=15, n_estimators=100;, score=0.870 total time=   0.6s
# [CV 5/5; 13/20] START criterion=entropy, max_depth=15, n_estimators=100.........
# [CV 5/5; 13/20] END criterion=entropy, max_depth=15, n_estimators=100;, score=0.882 total time=   0.5s
# [CV 1/5; 14/20] START criterion=gini, max_depth=29, n_estimators=1000...........
# [CV 1/5; 14/20] END criterion=gini, max_depth=29, n_estimators=1000;, score=0.880 total time=   4.6s
# [CV 2/5; 14/20] START criterion=gini, max_depth=29, n_estimators=1000...........
# [CV 2/5; 14/20] END criterion=gini, max_depth=29, n_estimators=1000;, score=0.887 total time=   4.3s
# [CV 3/5; 14/20] START criterion=gini, max_depth=29, n_estimators=1000...........
# [CV 3/5; 14/20] END criterion=gini, max_depth=29, n_estimators=1000;, score=0.890 total time=   4.2s
# [CV 4/5; 14/20] START criterion=gini, max_depth=29, n_estimators=1000...........
# [CV 4/5; 14/20] END criterion=gini, max_depth=29, n_estimators=1000;, score=0.877 total time=   4.5s
# [CV 5/5; 14/20] START criterion=gini, max_depth=29, n_estimators=1000...........
# [CV 5/5; 14/20] END criterion=gini, max_depth=29, n_estimators=1000;, score=0.860 total time=   4.8s
# [CV 1/5; 15/20] START criterion=gini, max_depth=16, n_estimators=1300...........
# [CV 1/5; 15/20] END criterion=gini, max_depth=16, n_estimators=1300;, score=0.882 total time=   5.7s
# [CV 2/5; 15/20] START criterion=gini, max_depth=16, n_estimators=1300...........
# [CV 2/5; 15/20] END criterion=gini, max_depth=16, n_estimators=1300;, score=0.887 total time=   6.1s
# [CV 3/5; 15/20] START criterion=gini, max_depth=16, n_estimators=1300...........
# [CV 3/5; 15/20] END criterion=gini, max_depth=16, n_estimators=1300;, score=0.897 total time=   5.8s
# [CV 4/5; 15/20] START criterion=gini, max_depth=16, n_estimators=1300...........
# [CV 4/5; 15/20] END criterion=gini, max_depth=16, n_estimators=1300;, score=0.873 total time=   5.6s
# [CV 5/5; 15/20] START criterion=gini, max_depth=16, n_estimators=1300...........
# [CV 5/5; 15/20] END criterion=gini, max_depth=16, n_estimators=1300;, score=0.865 total time=   5.8s
# [CV 1/5; 16/20] START criterion=gini, max_depth=28, n_estimators=1100...........
# [CV 1/5; 16/20] END criterion=gini, max_depth=28, n_estimators=1100;, score=0.887 total time=   4.7s
# [CV 2/5; 16/20] START criterion=gini, max_depth=28, n_estimators=1100...........
# [CV 2/5; 16/20] END criterion=gini, max_depth=28, n_estimators=1100;, score=0.890 total time=   4.9s
# [CV 3/5; 16/20] START criterion=gini, max_depth=28, n_estimators=1100...........
# [CV 3/5; 16/20] END criterion=gini, max_depth=28, n_estimators=1100;, score=0.895 total time=   4.8s
# [CV 4/5; 16/20] START criterion=gini, max_depth=28, n_estimators=1100...........
# [CV 4/5; 16/20] END criterion=gini, max_depth=28, n_estimators=1100;, score=0.873 total time=   4.8s
# [CV 5/5; 16/20] START criterion=gini, max_depth=28, n_estimators=1100...........
# [CV 5/5; 16/20] END criterion=gini, max_depth=28, n_estimators=1100;, score=0.863 total time=   4.8s
# [CV 1/5; 17/20] START criterion=gini, max_depth=13, n_estimators=1400...........
# [CV 1/5; 17/20] END criterion=gini, max_depth=13, n_estimators=1400;, score=0.880 total time=   6.8s
# [CV 2/5; 17/20] START criterion=gini, max_depth=13, n_estimators=1400...........
# [CV 2/5; 17/20] END criterion=gini, max_depth=13, n_estimators=1400;, score=0.890 total time=   6.0s
# [CV 3/5; 17/20] START criterion=gini, max_depth=13, n_estimators=1400...........
# [CV 3/5; 17/20] END criterion=gini, max_depth=13, n_estimators=1400;, score=0.905 total time=   5.9s
# [CV 4/5; 17/20] START criterion=gini, max_depth=13, n_estimators=1400...........
# [CV 4/5; 17/20] END criterion=gini, max_depth=13, n_estimators=1400;, score=0.865 total time=   6.9s
# [CV 5/5; 17/20] START criterion=gini, max_depth=13, n_estimators=1400...........
# [CV 5/5; 17/20] END criterion=gini, max_depth=13, n_estimators=1400;, score=0.863 total time=   6.2s
# [CV 1/5; 18/20] START criterion=entropy, max_depth=4, n_estimators=1200.........
# [CV 1/5; 18/20] END criterion=entropy, max_depth=4, n_estimators=1200;, score=0.823 total time=   4.8s
# [CV 2/5; 18/20] START criterion=entropy, max_depth=4, n_estimators=1200.........
# [CV 2/5; 18/20] END criterion=entropy, max_depth=4, n_estimators=1200;, score=0.815 total time=   4.5s
# [CV 3/5; 18/20] START criterion=entropy, max_depth=4, n_estimators=1200.........
# [CV 3/5; 18/20] END criterion=entropy, max_depth=4, n_estimators=1200;, score=0.843 total time=   4.7s
# [CV 4/5; 18/20] START criterion=entropy, max_depth=4, n_estimators=1200.........
# [CV 4/5; 18/20] END criterion=entropy, max_depth=4, n_estimators=1200;, score=0.830 total time=   4.5s
# [CV 5/5; 18/20] START criterion=entropy, max_depth=4, n_estimators=1200.........
# [CV 5/5; 18/20] END criterion=entropy, max_depth=4, n_estimators=1200;, score=0.823 total time=   4.6s
# [CV 1/5; 19/20] START criterion=gini, max_depth=14, n_estimators=500............
# [CV 1/5; 19/20] END criterion=gini, max_depth=14, n_estimators=500;, score=0.885 total time=   2.2s
# [CV 2/5; 19/20] START criterion=gini, max_depth=14, n_estimators=500............
# [CV 2/5; 19/20] END criterion=gini, max_depth=14, n_estimators=500;, score=0.887 total time=   2.2s
# [CV 3/5; 19/20] START criterion=gini, max_depth=14, n_estimators=500............
# [CV 3/5; 19/20] END criterion=gini, max_depth=14, n_estimators=500;, score=0.902 total time=   2.3s
# [CV 4/5; 19/20] START criterion=gini, max_depth=14, n_estimators=500............
# [CV 4/5; 19/20] END criterion=gini, max_depth=14, n_estimators=500;, score=0.882 total time=   2.6s
# [CV 5/5; 19/20] START criterion=gini, max_depth=14, n_estimators=500............
# [CV 5/5; 19/20] END criterion=gini, max_depth=14, n_estimators=500;, score=0.875 total time=   2.4s
# [CV 1/5; 20/20] START criterion=gini, max_depth=22, n_estimators=100............
# [CV 1/5; 20/20] END criterion=gini, max_depth=22, n_estimators=100;, score=0.870 total time=   0.5s
# [CV 2/5; 20/20] START criterion=gini, max_depth=22, n_estimators=100............
# [CV 2/5; 20/20] END criterion=gini, max_depth=22, n_estimators=100;, score=0.885 total time=   0.5s
# [CV 3/5; 20/20] START criterion=gini, max_depth=22, n_estimators=100............
# [CV 3/5; 20/20] END criterion=gini, max_depth=22, n_estimators=100;, score=0.887 total time=   0.6s
# [CV 4/5; 20/20] START criterion=gini, max_depth=22, n_estimators=100............
# [CV 4/5; 20/20] END criterion=gini, max_depth=22, n_estimators=100;, score=0.868 total time=   0.5s
# [CV 5/5; 20/20] START criterion=gini, max_depth=22, n_estimators=100............
# [CV 5/5; 20/20] END criterion=gini, max_depth=22, n_estimators=100;, score=0.860 total time=   0.5s
# Best score: 0.8905
# Best parameters set:
# 	criterion: entropy
# 	max_depth: 19
# 	n_estimators: 1200

# %% [markdown]
# ### Pipeline Search

# %%
train = pd.read_csv('/kaggle/input/mobile-price-dataset/mobile_price_train.csv')
test = pd.read_csv('/kaggle/input/mobile-price-dataset/mobile_price_test.csv')

# %%
train.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         21       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
# 3        1             0     0            2
# 4        1             1     0            1
#
# [5 rows x 21 columns]

# %%
X = train.drop("price_range", axis=1)
y = train["price_range"]

# define pipeline
pipe = Pipeline([
    ("scaler", StandardScaler()),
    ("svm", SVC())
])

# parameter grid
param_grid = {
    "svm__C": [0.1, 1, 10],
    "svm__gamma": ["scale", 0.01, 0.1],
    "svm__kernel": ["rbf"]
}

# grid search
grid = GridSearchCV(
    estimator=pipe,
    param_grid=param_grid,
    cv=5,
    scoring="accuracy",
    n_jobs=-1,
    verbose=2
)

grid.fit(X, y)

print("Best Score:", grid.best_score_)
print("Best Params:", grid.best_params_)

# Final model
best_model = grid.best_estimator_
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# Best Score: 0.9260000000000002
# Best Params: {'svm__C': 1, 'svm__gamma': 0.01, 'svm__kernel': 'rbf'}

# %%
# define pipeline
pipe = Pipeline([
    ("scaler", StandardScaler()),
    ("pca", PCA()),
    ("svm", SVC())
])

# parameter grid
param_grid = {
    "pca__n_components": [5, 10, 15],
    "svm__C": [1, 5, 10],
    "svm__gamma": ["scale", 0.01]
}

# grid search
grid = GridSearchCV(
    estimator=pipe,
    param_grid=param_grid,
    cv=5,
    scoring="accuracy",
    n_jobs=-1,
    verbose=2
)

grid.fit(X, y)

print("Best Score:", grid.best_score_)
print("Best Params:", grid.best_params_)

# Final model
best_model = grid.best_estimator_
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# Best Score: 0.8629999999999999
# Best Params: {'pca__n_components': 15, 'svm__C': 5, 'svm__gamma': 0.01}
