# %% [markdown]
# <a href="https://www.kaggle.com/code/samithsachidanandan/data-cleaning-basics?scriptVersionId=221052469" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input/covid19'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# ##  Importing the Library and Loading the Data.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
df =pd.read_csv(r'/kaggle/input/covid19/covid_19_data.csv')

# %% [markdown]
# ## Inspecting the Data.

# %%
df       # Veiwing the complete dataset

# %%
df.head() # Veiwing the 1st 5 rows of the  dataset

# %%
df.tail() # Veiwing the last 5 rows of the  dataset

# %% [markdown]
# ## Renaming the columns

# %%
df.rename(columns={'ObservationDate':'Date','Province/State': 'Province', 'Country/Region': 'Country' }, inplace=True)

# %% [markdown]
# ## Summary of Dataset

# %%
df.info()

# %%
df.describe()

# %% [markdown]
# ## Coverting the Date Datatype

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %% [markdown]
# ## Standardize Column Names

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')  # Uniform style

# %% [markdown]
# #### Not required in this Dataset

# %% [markdown]
# ## Checking for the Duplicates and dropping the Duplicates

# %%
df.duplicated().sum()

# %%
 df.drop_duplicates(inplace=True)

# %%
df.isna().sum().sort_values()

# %%
df =df.fillna('NA')

# %%
 df.to_csv('cleaned_file.csv', index=False)
