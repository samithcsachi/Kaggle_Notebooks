# %% [markdown]
# <a href="https://www.kaggle.com/code/samithsachidanandan/lstm-time-series-forecasting-with-deep-learning?scriptVersionId=297674620" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Import Libraries

# %%
import tensorflow as tf 
import os 
import pandas as pd
import numpy as np

os.environ["TF_CPP_MIN_LOG_LEVEL"] = '2'

import warnings
warnings.filterwarnings("ignore")
# Out:
# 2026-02-14 11:32:01.766770: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771068721.994419      17 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771068722.068884      17 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771068722.593401      17 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !wget https://storage.googleapis.com/tensorflow/tf-keras-datasets/jena_climate_2009_2016.csv.zip

# !unzip jena_climate_2009_2016.csv.zip
# Out:
# --2026-02-14 11:32:19--  https://storage.googleapis.com/tensorflow/tf-keras-datasets/jena_climate_2009_2016.csv.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.251.8.207, 74.125.204.207, 173.194.174.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.251.8.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13568290 (13M) [application/zip]
# Saving to: ‘jena_climate_2009_2016.csv.zip’
#
# jena_climate_2009_2 100%[===================>]  12.94M  8.77MB/s    in 1.5s
#
# 2026-02-14 11:32:22 (8.77 MB/s) - ‘jena_climate_2009_2016.csv.zip’ saved [13568290/13568290]
#
# Archive:  jena_climate_2009_2016.csv.zip
#   inflating: jena_climate_2009_2016.csv

# %%
df = pd.read_csv("jena_climate_2009_2016.csv")

# %%
df.head()
# Out:
#              Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 0  01.01.2009 00:10:00    996.52     -8.02    265.40        -8.90    93.3
# 1  01.01.2009 00:20:00    996.57     -8.41    265.01        -9.28    93.4
# 2  01.01.2009 00:30:00    996.53     -8.51    264.91        -9.31    93.9
# 3  01.01.2009 00:40:00    996.51     -8.31    265.12        -9.07    94.2
# 4  01.01.2009 00:50:00    996.51     -8.27    265.15        -9.04    94.1
#
#    VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  \
# 0          3.33          3.11          0.22       1.94             3.12
# 1          3.23          3.02          0.21       1.89             3.03
# 2          3.21          3.01          0.20       1.88             3.02
# 3          3.26          3.07          0.19       1.92             3.08
# 4          3.27          3.08          0.19       1.92             3.09
#
#    rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# ...

# %%
df = df[5::6]
df
# Out:
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 5       01.01.2009 01:00:00    996.50     -8.05    265.38        -8.78
# 11      01.01.2009 02:00:00    996.62     -8.88    264.54        -9.77
# 17      01.01.2009 03:00:00    996.84     -8.81    264.59        -9.66
# 23      01.01.2009 04:00:00    996.99     -9.05    264.34       -10.02
# 29      01.01.2009 05:00:00    997.46     -9.63    263.72       -10.65
# ...                     ...       ...       ...       ...          ...
# 420521  31.12.2016 19:10:00   1002.18     -0.98    272.01        -5.36
# 420527  31.12.2016 20:10:00   1001.40     -1.40    271.66        -6.84
# 420533  31.12.2016 21:10:00   1001.19     -2.75    270.32        -6.90
# 420539  31.12.2016 22:10:00   1000.65     -2.89    270.22        -7.15
# 420545  31.12.2016 23:10:00   1000.11     -3.93    269.23        -8.09
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# ...

# %%
df.index = pd.to_datetime(df['Date Time'], format='%d.%m.%Y %H:%M:%S' )
df[:26]
# Out:
#                                Date Time  p (mbar)  T (degC)  Tpot (K)  \
# Date Time
# 2009-01-01 01:00:00  01.01.2009 01:00:00    996.50     -8.05    265.38
# 2009-01-01 02:00:00  01.01.2009 02:00:00    996.62     -8.88    264.54
# 2009-01-01 03:00:00  01.01.2009 03:00:00    996.84     -8.81    264.59
# 2009-01-01 04:00:00  01.01.2009 04:00:00    996.99     -9.05    264.34
# 2009-01-01 05:00:00  01.01.2009 05:00:00    997.46     -9.63    263.72
# 2009-01-01 06:00:00  01.01.2009 06:00:00    997.71     -9.67    263.66
# 2009-01-01 07:00:00  01.01.2009 07:00:00    998.33     -9.17    264.12
# 2009-01-01 08:00:00  01.01.2009 08:00:00    999.17     -8.10    265.12
# 2009-01-01 09:00:00  01.01.2009 09:00:00    999.69     -7.66    265.52
# 2009-01-01 10:00:00  01.01.2009 10:00:00   1000.27     -7.04    266.10
# 2009-01-01 11:00:00  01.01.2009 11:00:00   1000.87     -7.41    265.68
# 2009-01-01 12:00:00  01.01.2009 12:00:00   1000.30     -6.87    266.27
# ...

# %%
temp  =df['T (degC)']
temp.plot()
# Out:
# <Axes: xlabel='Date Time'>

# %%
def df_to_X_y (df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y= []
    for i in range (len(df_as_np) - window_size):
        row =[[a] for a in df_as_np[i:i+5]]
        X.append(row)
        label = df_as_np[i+5]
        y.append(label)

    return np.array(X), np.array(y)

# %%
WINDOW_SIZE = 5 
X,y = df_to_X_y(temp,WINDOW_SIZE )
X.shape, y.shape
# Out:
# ((70086, 5, 1), (70086,))

# %%
X_train, y_train = X[:60000], y[:60000]
X_val, y_val =  X[60000:65000], y[60000:65000]
X_test, y_test = X[65000:], y[65000:]
X_train.shape, y_train.shape,X_val.shape,y_val.shape, X_test.shape, y_test.shape
# Out:
# ((60000, 5, 1), (60000,), (5000, 5, 1), (5000,), (5086, 5, 1), (5086,))

# %%
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

model1 = Sequential()
model1.add(InputLayer((5,1)))
model1.add(LSTM(64))
model1.add(Dense(8, 'relu'))
model1.add(Dense(1, 'linear'))


model1.summary()
# Out:
# 2026-02-14 11:32:25.999508: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 64)             │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 8)              │           520 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,425 (68.07 KB)
#  Trainable params: 17,425 (68.07 KB)
# ...

# %%
cp = ModelCheckpoint('model1.keras', save_best_only=True)
model1.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model1.fit(X_train, y_train, validation_data=(X_val, y_val), epochs =10, callbacks=[cp] )
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 67.1302 - root_mean_squared_error: 7.9406 - val_loss: 1.1984 - val_root_mean_squared_error: 1.0947
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 2.6558 - root_mean_squared_error: 1.6225 - val_loss: 0.6235 - val_root_mean_squared_error: 0.7896
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.9757 - root_mean_squared_error: 0.9874 - val_loss: 0.5304 - val_root_mean_squared_error: 0.7283
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.7579 - root_mean_squared_error: 0.8698 - val_loss: 0.5230 - val_root_mean_squared_error: 0.7232
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.6772 - root_mean_squared_error: 0.8229 - val_loss: 0.4972 - val_root_mean_squared_error: 0.7051
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.6565 - root_mean_squared_error: 0.8102 - val_loss: 0.5161 - val_root_mean_squared_error: 0.7184
# ...

# %%
from tensorflow.keras.models import load_model


model1 = load_model('model1.keras')

# %%
train_predictions = model1.predict(X_train).flatten()
train_results = pd.DataFrame(data={'Train Predictions': train_predictions, 'Actuals': y_train})
train_results
# Out:
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step
#        Train Predictions  Actuals
# 0              -9.766876    -9.67
# 1              -9.578460    -9.17
# 2              -8.747305    -8.10
# 3              -7.208420    -7.66
# 4              -7.207200    -7.04
# ...                  ...      ...
# 59995           5.953241     6.07
# 59996           7.203634     9.88
# 59997          12.163984    13.53
# 59998          15.879520    15.43
# 59999          16.496927    15.54
#
# [60000 rows x 2 columns]

# %%
import matplotlib.pyplot as plt 

plt.plot(train_results['Train Predictions'][:100])
plt.plot(train_results['Actuals'][:100])

# %%
val_predictions = model1.predict(X_val).flatten()
val_results = pd.DataFrame(data={'Val Predictions': train_predictions, 'Actuals': y_train})
val_results
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#        Val Predictions  Actuals
# 0            -9.766876    -9.67
# 1            -9.578460    -9.17
# 2            -8.747305    -8.10
# 3            -7.208420    -7.66
# 4            -7.207200    -7.04
# ...                ...      ...
# 59995         5.953241     6.07
# 59996         7.203634     9.88
# 59997        12.163984    13.53
# 59998        15.879520    15.43
# 59999        16.496927    15.54
#
# [60000 rows x 2 columns]

# %%
plt.plot(val_results['Val Predictions'][:100])
plt.plot(val_results['Actuals'][:100])
