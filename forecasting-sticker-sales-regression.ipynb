# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_1 = pd.read_csv ('/kaggle/input/playground-series-s5e1/train.csv')
df_2 = pd.read_csv ('/kaggle/input/playground-series-s5e1/test.csv')
if 'num_sold' not in df_2.columns:
    df_2['num_sold'] = 0
df = pd.concat([df_1, df_2], axis = 0)
df = df.set_index('id')

# %%
df.head()

# %%
df_null = df[df.isnull().sum()[df.isnull().sum()>0].index]

# %%
df_null.head()

# %%
sns.heatmap(df_null.isnull())

# %%
df.isna().sum()

# %%
df.describe()

# %%
df.info()

# %%
df['date'] = pd.to_datetime(df['date']) 
df['country'] = df['country'].astype('category')  
df['store'] = df['store'].astype('category')  
df['product'] = df['product'].astype('category')

# %%
def create_features(df):
    """
    Create time series features based on time series index.
    """
    df = df.copy()

   
    df['month'] = df['date'].dt.month
    df['year'] = df['date'].dt.year
    df['dayofyear'] = df['date'].dt.dayofyear
    df['dayofmonth'] = df['date'].dt.day
    df['weekofyear'] = df['date'].dt.isocalendar().week

    return df

df = create_features(df)

# %%
df.head()

# %%
training_data = df[0:len(df_1)]
testing_data = df[len(df_1):]
testing_data = testing_data.drop(columns='num_sold')
