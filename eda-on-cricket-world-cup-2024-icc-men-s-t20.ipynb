# %% [markdown]
# <a href="https://www.kaggle.com/code/samithsachidanandan/eda-on-cricket-world-cup-2024-icc-men-s-t20?scriptVersionId=229813555" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <a id="dataset-analysis"></a>
# <p style="padding:30px;background-color:#2e3b4e;margin:0;color:#e8e8e8;font-family:Arial,sans-serif;font-size:250%;text-align:center;border-radius:10px;overflow:hidden;font-weight:800">
#     🚀 Complete EDA on Cricket World Cup 2024 ICC Men's T20  🚀

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/icc-mens-t20-worldcup/ICC Mens T20 Worldcup.csv

# %% [markdown]
# #### Exploratory Data Analysis of Cricket World Cup 2024 ICC Men's T20 goes through the player analysis of matches and overall tournement. It also goes throught the each stages of the tournement.

# %% [markdown]
# <a id="dataset-analysis"></a>
# <p style="padding:30px;background-color:#2e3b4e;margin:0;color:#e8e8e8;font-family:Arial,sans-serif;font-size:250%;text-align:center;border-radius:10px;overflow:hidden;font-weight:800">
#     🚀 Libraries 🚀

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns


import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# <a id="dataset-analysis"></a>
# <p style="padding:30px;background-color:#2e3b4e;margin:0;color:#e8e8e8;font-family:Arial,sans-serif;font-size:250%;text-align:center;border-radius:10px;overflow:hidden;font-weight:800">
#     🚀 Loading the Dataset  🚀

# %%
df = pd.read_csv('/kaggle/input/icc-mens-t20-worldcup/ICC Mens T20 Worldcup.csv')

# %% [markdown]
# <a id="dataset-analysis"></a>
# <p style="padding:30px;background-color:#2e3b4e;margin:0;color:#e8e8e8;font-family:Arial,sans-serif;font-size:250%;text-align:center;border-radius:10px;overflow:hidden;font-weight:800">
#     🚀 Data Exploring + Statistical Analysis  🚀

# %%
df.head()
# Out:
#   Match No.                  Date  \
# 0       1st  Saturday,June 1,2024
# 1       2nd    Sunday,June 2,2024
# 2       3rd    Sunday,June 2,2024
# 3       4th    Monday,June 3,2024
# 4       5th    Monday,June 3,2024
#
#                                                Venue          1st Team  \
# 0                      Grand Prairie Stadium, Dallas            Canada
# 1                         Providence Stadium, Guyana  Papua New Guinea
# 2              Kensington Oval, Bridgetown, Barbados              Oman
# 3  Nassau County International Cricket Stadium, N...         Sri Lanka
# 4                         Providence Stadium, Guyana       Afghanistan
#
#                   2nd Team    Stage             Toss Winning Toss Decision  \
# 0  United State Of America  Group A  United State Of America      Fielding
# 1              Afghanistan  Group C              Afghanistan      Fielding
# 2                  Namibia  Group B                  Namibia      Fielding
# ...

# %%
df.shape
# Out:
# (55, 22)

# %%
df.columns
# Out:
# Index(['Match No.', 'Date', 'Venue', '1st Team', '2nd Team', 'Stage',
#        'Toss Winning', 'Toss Decision', 'First Innings Score',
#        'Fall of wickets First Innings', 'Second Innings Score',
#        'Fall of wickets Second Innings', 'Winners', 'Method', 'Won by',
#        'Winning Margin', 'Top Scorer', 'Highest Score', 'Best Bowler',
#        'Best Bowler Figure(Wickets Taken)',
#        'Best Bowler Figure(Runs Recieved)', 'Player Of The Match'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Match No.                          55 non-null     object
#  1   Date                               55 non-null     object
#  2   Venue                              55 non-null     object
#  3   1st Team                           55 non-null     object
#  4   2nd Team                           55 non-null     object
#  5   Stage                              55 non-null     object
#  6   Toss Winning                       55 non-null     object
#  7   Toss Decision                      55 non-null     object
#  8   First Innings Score                55 non-null     object
#  9   Fall of wickets First Innings      55 non-null     object
#  10  Second Innings Score               55 non-null     object
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')  # Convert to datetime
df['First Innings Score'] = pd.to_numeric(df['First Innings Score'], errors='coerce')  # Convert to numeric
df['Fall of wickets First Innings'] = pd.to_numeric(df['Fall of wickets First Innings'], errors='coerce')
df['Second Innings Score'] = pd.to_numeric(df['Second Innings Score'], errors='coerce')
df['Fall of wickets Second Innings'] = pd.to_numeric(df['Fall of wickets Second Innings'], errors='coerce')
df['Winning Margin'] = pd.to_numeric(df['Winning Margin'], errors='coerce')
df['Highest Score'] = pd.to_numeric(df['Highest Score'], errors='coerce')
df['Best Bowler Figure(Wickets Taken)'] = pd.to_numeric(df['Best Bowler Figure(Wickets Taken)'], errors='coerce')
df['Best Bowler Figure(Runs Recieved)'] = pd.to_numeric(df['Best Bowler Figure(Runs Recieved)'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Match No.                          55 non-null     object
#  1   Date                               20 non-null     datetime64[ns]
#  2   Venue                              55 non-null     object
#  3   1st Team                           55 non-null     object
#  4   2nd Team                           55 non-null     object
#  5   Stage                              55 non-null     object
#  6   Toss Winning                       55 non-null     object
#  7   Toss Decision                      55 non-null     object
#  8   First Innings Score                52 non-null     float64
#  9   Fall of wickets First Innings      52 non-null     float64
#  10  Second Innings Score               51 non-null     float64
# ...

# %%
df.describe()
# Out:
#                       Date  First Innings Score  \
# count                   20            52.000000
# mean   2024-06-05 10:48:00           133.865385
# min    2024-06-01 00:00:00            40.000000
# 25%    2024-06-03 18:00:00           106.000000
# 50%    2024-06-05 12:00:00           131.500000
# 75%    2024-06-07 06:00:00           166.250000
# max    2024-06-09 00:00:00           218.000000
# std                    NaN            44.012043
#
#        Fall of wickets First Innings  Second Innings Score  \
# count                      52.000000             51.000000
# mean                        7.423077            116.372549
# min                         0.000000             39.000000
# 25%                         5.000000             98.500000
# 50%                         7.000000            113.000000
# 75%                        10.000000            135.000000
# max                        10.000000            197.000000
# ...

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Date                                 35
# Fall of wickets Second Innings        4
# Best Bowler Figure(Runs Recieved)     4
# Best Bowler Figure(Wickets Taken)     4
# Highest Score                         4
# Winning Margin                        4
# Second Innings Score                  4
# First Innings Score                   3
# Fall of wickets First Innings         3
# Method                                0
# Best Bowler                           0
# Top Scorer                            0
# Won by                                0
# Match No.                             0
# Winners                               0
# Toss Decision                         0
# Toss Winning                          0
# Stage                                 0
# 2nd Team                              0
# 1st Team                              0
# Venue                                 0
# Player Of The Match                   0
# dtype: int64

# %%
df.nunique()
# Out:
# Match No.                            55
# Date                                  9
# Venue                                 9
# 1st Team                             19
# 2nd Team                             18
# Stage                                 9
# Toss Winning                         19
# Toss Decision                         3
# First Innings Score                  40
# Fall of wickets First Innings         8
# Second Innings Score                 42
# Fall of wickets Second Innings       11
# Winners                              17
# Method                                3
# Won by                                3
# Winning Margin                       28
# Top Scorer                           39
# Highest Score                        37
# Best Bowler                          41
# Best Bowler Figure(Wickets Taken)     7
# Best Bowler Figure(Runs Recieved)    27
# Player Of The Match                  44
# dtype: int64

# %%
teams = list(set(df['1st Team'].unique().tolist() + df['2nd Team'].unique().tolist()))
print("Teams played the World Cup")
for i in range(len(teams)):
    print(f"{i+1} : {teams[i]}")
# Out:
# Teams played the World Cup
# 1 : South Africa
# 2 : Ireland
# 3 : Uganda
# 4 : Netherlands
# 5 : West Indies
# 6 : Oman
# 7 : Bangladesh
# 8 : Nepal
# 9 : Sri Lanka
# 10 : Pakistan
# 11 : New Zealand
# 12 : Canada
# 13 : Australia
# 14 : United State Of America
# 15 : Afghanistan
# 16 : Papua New Guinea
# 17 : India
# 18 : Namibia
# 19 : Scotland
# 20 : England

# %%
df['Toss Decision'].unique()
# Out:
# array(['Fielding', 'Batting', 'Rain'], dtype=object)

# %% [markdown]
# <a id="dataset-analysis"></a>
# <p style="padding:30px;background-color:#2e3b4e;margin:0;color:#e8e8e8;font-family:Arial,sans-serif;font-size:250%;text-align:center;border-radius:10px;overflow:hidden;font-weight:800">
#     🚀 Creaing New Columns for Further Analysis  🚀

# %%
df['1st Batting'] = np.where(
    df['Toss Decision'] == 'Batting',  
    df['Toss Winning'],               
    np.where(                         
        df['Toss Winning'] == df['1st Team'], 
        df['2nd Team'],              
        df['1st Team']  ))             


df['1st Bowling'] = np.where(
        df['Toss Decision'] == 'Fielding',  
        df['Toss Winning'],               
        np.where(                         
            df['Toss Winning'] == df['1st Team'], 
            df['2nd Team'],              
            df['1st Team']))
df = df[df['1st Batting'] != df['1st Bowling']]

# %% [markdown]
# <a id="dataset-analysis"></a>
# <p style="padding:30px;background-color:#2e3b4e;margin:0;color:#e8e8e8;font-family:Arial,sans-serif;font-size:250%;text-align:center;border-radius:10px;overflow:hidden;font-weight:800">
#     🚀 Functions for Data Visualization  🚀

# %%
def OverallStats(df):

        
    Highest_Score_1stinnings = df.groupby('1st Batting')['First Innings Score'].max().reset_index().sort_values(by='First Innings Score', ascending=False)
    
    
    Highest_Score_2ndinnings = df.groupby('1st Bowling')['Second Innings Score'].max().reset_index().sort_values(by='Second Innings Score', ascending=False)

   
    df['Win_Runs'] = np.where(df['Won by'] == 'Runs', df['Winning Margin'], 0)
    df['Win_Wickets'] = np.where(df['Won by'] == 'Wickets', df['Winning Margin'], 0)

   
    Runs = df[df['Win_Runs'] != 0][['Winners', 'Win_Runs']].sort_values(by='Win_Runs', ascending=False)
    Wickets = df[df['Win_Wickets'] != 0][['Winners', 'Win_Wickets']].sort_values(by='Win_Wickets', ascending=False)

    
    Top_10_Score = df.groupby('Top Scorer')['Highest Score'].max().reset_index().sort_values(by='Highest Score', ascending=False).head(10)
    Top_10_Wickets = df.groupby('Best Bowler')['Best Bowler Figure(Wickets Taken)'].max().reset_index().sort_values(by='Best Bowler Figure(Wickets Taken)', ascending=False).head(10)

    
    Most_POM = df['Player Of The Match'].value_counts().head(10)
    Most_Wins = df['Winners'].value_counts()
    Venue = df['Venue'].value_counts()

    
    return Highest_Score_1stinnings, Highest_Score_2ndinnings, Runs, Wickets, Top_10_Wickets, Top_10_Score, Most_POM, Most_Wins, Venue, df

Highest_Score_1stinnings, Highest_Score_2ndinnings, Runs, Wickets, Top_10_Wickets, Top_10_Score, Most_POM, Most_Wins, Venue, df = OverallStats(df)

# %%
def plot_scatter(data, x_col,y_col,title, x_label, y_label, hue=None, size=None, style=None, palette='viridis', figsize=(12, 10), rotation=45):

    plt.figure(figsize=figsize)
    ax = sns.scatterplot(data=data, x=x_col, y=y_col, hue=hue, size=size, style=style, palette=palette)
    
    

    for i, row in data.iterrows():
        ax.annotate(f'{row[y_col]:.0f}', 
                    (row[x_col], row[y_col]), 
                    ha='center', va='bottom', 
                    fontsize=10, color='black', 
                    xytext=(0, 5), textcoords='offset points')

    plt.xticks(rotation=rotation, ha='right')
    plt.title(title, fontsize=16)
    plt.xlabel(x_label, fontsize=12)
    plt.ylabel(y_label, fontsize=12)
    plt.tight_layout()
    plt.show()

# %%
def plot_bar(data, x_col, y_col, title, x_label, y_label, palette='viridis', figsize=(12, 10), rotation=45):

    plt.figure(figsize=figsize)
    ax = sns.barplot(data=data, x=x_col, y=y_col, palette=palette)

    for p in ax.patches:
        ax.annotate(f'{p.get_height():.0f}', 
                    (p.get_x() + p.get_width() / 2., p.get_height()), 
                    ha='center', va='center', 
                    fontsize=12, color='black', 
                    xytext=(0, 5), textcoords='offset points')

    plt.xticks(rotation=rotation, ha='right')  
    plt.title(title, fontsize=16)
    plt.xlabel(x_label, fontsize=12)
    plt.ylabel(y_label, fontsize=12)
    plt.tight_layout()
    plt.show()

# %%
def plot():

    plot_bar(data=Highest_Score_1stinnings, x_col='1st Batting', y_col='First Innings Score',title= 'Highest First Innings Scores by Team', x_label= 'Team',y_label='Maximum First Innings Score', palette='viridis')
    plot_bar(data=Highest_Score_2ndinnings, x_col='1st Bowling', y_col='Second Innings Score',title= 'Highest Second Innings Scores by Team', x_label= 'Team',y_label='Maximum Second Innings Score', palette='viridis')
    plot_scatter(data=Runs, x_col='Winners', y_col='Win_Runs',title= 'Distribution of Winning Runs', x_label= 'Country',y_label='Winning Runs', palette='viridis')
    plot_scatter(data=Wickets, x_col='Winners', y_col='Win_Wickets',title= 'Distribution of Winning Wickets', x_label= 'Country',y_label='Winning Wickets', palette='viridis')
    plot_bar(data=Top_10_Score, x_col='Top Scorer', y_col='Highest Score',title= 'Highest Score Innings', x_label= 'Player',y_label='Highest Score', palette='deep')
    plot_bar(data=Top_10_Wickets, x_col='Best Bowler', y_col='Best Bowler Figure(Wickets Taken)',title= 'Highest Wickets Innings', x_label= 'Player',y_label='Highest Wickets', palette='deep')
    plot_bar(data=df, x_col=Most_POM.index, y_col=Most_POM.values,title= 'Player of the Matches - Top 10', x_label= 'Player',y_label='Number of Matches', palette='pastel')
    plot_bar(data=df, x_col=Most_Wins.index, y_col=Most_Wins.values,title= 'Most Matches Won by Country', x_label= 'Country',y_label='Number of the Matches Won', palette='dark')
    plot_bar(data=df, x_col=Venue.index, y_col=Venue.values,title= 'No of Matches by Venue', x_label= 'Venue',y_label='Number of the Matches', palette='muted')

# %% [markdown]
# ### Plotting the Charts

# %%
plot()

# %%
df['Stage'].unique()
# Out:
# array(['Group A', 'Group C', 'Group B', 'Group D', 'Group 2', 'Group 1',
#        '1st Semi-Final', '2nd Semi-Final', 'Final'], dtype=object)

# %% [markdown]
# <a id="dataset-analysis"></a>
# <p style="padding:30px;background-color:#2e3b4e;margin:0;color:#e8e8e8;font-family:Arial,sans-serif;font-size:250%;text-align:center;border-radius:10px;overflow:hidden;font-weight:800">
#     🚀 Spliting the Dataset into Differnet Stages 🚀

# %%
df_group_stages = df[df['Stage'].isin(['Group A', 'Group C', 'Group B', 'Group D'])]
df_supereight_stages = df[df['Stage'].isin(['Group 1', 'Group 2'])]
df_semi_final = df[df['Stage'].isin(['1st Semi-Final', '2nd Semi-Final'])]
df_final = df[df['Stage'].isin(['Final'])]

# %% [markdown]
# ### Group Stage Visualizations

# %%
Highest_Score_1stinnings, Highest_Score_2ndinnings, Runs, Wickets, Top_10_Wickets, Top_10_Score, Most_POM, Most_Wins, Venue, df = OverallStats(df_group_stages)
plot()

# %% [markdown]
# ### Super Eight Stage Visualizations

# %%
Highest_Score_1stinnings, Highest_Score_2ndinnings, Runs, Wickets, Top_10_Wickets, Top_10_Score, Most_POM, Most_Wins, Venue, df = OverallStats(df_supereight_stages)
plot()

# %% [markdown]
# ### Semi Final  Visualizations

# %%
Highest_Score_1stinnings, Highest_Score_2ndinnings, Runs, Wickets, Top_10_Wickets, Top_10_Score, Most_POM, Most_Wins, Venue, df = OverallStats(df_semi_final)
plot()

# %% [markdown]
# ### Final Analysis

# %%
Highest_Score_1stinnings, Highest_Score_2ndinnings, Runs, Wickets, Top_10_Wickets, Top_10_Score, Most_POM, Most_Wins, Venue, df = OverallStats(df_final)

# %%
print(f"Score in the 1st Innings: {Highest_Score_1stinnings['1st Batting'].values[0]} scored {Highest_Score_1stinnings['First Innings Score'].values[0]} runs.")
print(f"Score in the 2nd Innings: {Highest_Score_2ndinnings['1st Bowling'].values[0]} scored {Highest_Score_2ndinnings['Second Innings Score'].values[0]} runs.")
print(f"{Top_10_Score['Top Scorer'].values[0]} scored {Top_10_Score['Highest Score'].values[0]} runs ")
print(f"{Top_10_Wickets['Best Bowler'].values[0]} took {Top_10_Wickets['Best Bowler Figure(Wickets Taken)'].values[0]} wickets ")
print(f"{Highest_Score_1stinnings['1st Batting'].values[0]} won the match by  {Runs['Win_Runs'].values[0]} runs ")
# Out:
# Score in the 1st Innings: India scored 176.0 runs.
# Score in the 2nd Innings: South Africa scored 169.0 runs.
# Virat Kohli scored 76.0 runs
# Hardik Pandya took 3.0 wickets
# India won the match by  7.0 runs

# %% [markdown]
# <a id="dataset-analysis"></a>
# <p style="padding:30px;background-color:#2e3b4e;margin:0;color:#e8e8e8;font-family:Arial,sans-serif;font-size:250%;text-align:center;border-radius:10px;overflow:hidden;font-weight:800">
#     🚀 Thank You !!! 🚀
