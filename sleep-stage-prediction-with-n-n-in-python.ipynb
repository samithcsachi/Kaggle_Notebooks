# %% [markdown]
# ### Importing the Libraries

# %%
import os
from glob import glob

import numpy as np 
import matplotlib.pyplot as plt 

import torch
import torch.nn as nn

from sklearn.model_selection import train_test_split 
from sklearn.metrics import accuracy_score, classification_report,confusion_matrix

import mne

import warnings
warnings.filterwarnings("ignore", message=".*highpass filters.*")

# %% [markdown]
# ### Loading the Data

# %%
data_dir = '/kaggle/input/sleep-edf-database/sleep-cassette'

psg_files = sorted(glob(os.path.join(data_dir, '*PSG.edf')))
hypnogram_files = sorted(glob(os.path.join(data_dir, '*Hypnogram.edf')))

# %%
psg_files[:3]
# Out:
# ['/kaggle/input/sleep-edf-database/sleep-cassette/SC4001E0-PSG.edf',
#  '/kaggle/input/sleep-edf-database/sleep-cassette/SC4002E0-PSG.edf',
#  '/kaggle/input/sleep-edf-database/sleep-cassette/SC4011E0-PSG.edf']

# %%
hypnogram_files[:3]
# Out:
# ['/kaggle/input/sleep-edf-database/sleep-cassette/SC4001EC-Hypnogram.edf',
#  '/kaggle/input/sleep-edf-database/sleep-cassette/SC4002EC-Hypnogram.edf',
#  '/kaggle/input/sleep-edf-database/sleep-cassette/SC4011EH-Hypnogram.edf']

# %% [markdown]
# ### Data Exploration

# %%
raw_edf = mne.io.read_raw_edf(psg_files[0], preload=True, verbose=False)
# Out:
# /tmp/ipykernel_19/468361730.py:1: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_files[0], preload=True, verbose=False)
# /tmp/ipykernel_19/468361730.py:1: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_files[0], preload=True, verbose=False)

# %%
raw_edf
# Out:
# <RawEDF | SC4001E0-PSG.edf, 7 x 7950000 (79500.0 s), ~424.6 MiB, data loaded>

# %%
eeg_data = raw_edf.get_data()

# %%
eeg_data
# Out:
# array([[ 5.01684982e-06, -2.57875458e-06,  1.35970696e-06, ...,
#          5.29816850e-06, -4.64175824e-06,  6.61098901e-06],
#        [-2.46739927e-06,  1.46739927e-06, -4.09890110e-06, ...,
#         -3.04322344e-06, -3.71501832e-06,  1.75531136e-06],
#        [ 1.65086691e-05,  1.60158730e-05,  9.60952381e-06, ...,
#          6.97306471e-05,  8.05721612e-05,  1.02255189e-04],
#        ...,
#        [ 3.55200000e-06,  3.55321564e-06,  3.55442478e-06, ...,
#          3.54832977e-06,  3.54955549e-06,  3.55077942e-06],
#        [ 3.72064516e+01,  3.72051596e+01,  3.72039072e+01, ...,
#          3.72105629e+01,  3.72091535e+01,  3.72077830e+01],
#        [ 9.20000000e+02,  9.19950203e+02,  9.19892908e+02, ...,
#          9.20104028e+02,  9.20076946e+02,  9.20042260e+02]])

# %%
eeg_channel1 = eeg_data[0]

# %%
plt.plot(eeg_channel1[:2000])
plt.show()

# %%
fig, axs = plt.subplots(nrows=7, ncols=1, figsize=(16,8))

for i, ax in enumerate(axs):
    ax.plot(eeg_data[i][:1000])
plt.tight_layout()
plt.show()

# %%
eeg_channels = ['EEG Fpz-Cz', 'EEG Pz-Oz']

eeg_data = raw_edf.get_data(picks=eeg_channels)

# %%
fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(16,8))

fs = 100
N = 3000

for i, ax in enumerate(axs):
    x = np.arange(N) / fs 

    ax.plot(x, eeg_data[i][:N])
    ax.set_title(eeg_channels[i])
    ax.set_xlabel('Time (s)') 
    ax.set_ylabel('Voltage (µV)')
plt.tight_layout()
plt.show()

# %%
annotations = mne.read_annotations(hypnogram_files[0])

# %%
annotations
# Out:
# <Annotations | 154 segments: Sleep stage 1 (24), Sleep stage 2 (40), Sleep ...>

# %%
annotations.onset
# Out:
# array([    0., 30630., 30750., 31140., 31170., 31200., 31350., 31380.,
#        31440., 31500., 31530., 31650., 31680., 31800., 31830., 31890.,
#        31950., 32070., 32100., 32130., 32250., 32460., 32490., 32550.,
#        32670., 32700., 32850., 32910., 32940., 32970., 33000., 33120.,
#        33270., 33300., 33330., 33390., 33420., 33510., 35400., 35430.,
#        35640., 35700., 35790., 35940., 35970., 36840., 37020., 37260.,
#        37290., 37410., 37500., 37530., 38460., 38490., 38520., 38580.,
#        38610., 38640., 38670., 38700., 38730., 38760., 38910., 38970.,
#        39060., 39120., 39150., 39180., 39240., 39300., 39480., 39540.,
#        39570., 39600., 39870., 39900., 39960., 39990., 40200., 40230.,
#        40290., 40320., 40500., 41370., 41400., 41460., 41490., 41610.,
#        42480., 42510., 42540., 42570., 42870., 42900., 43290., 43320.,
#        43350., 43380., 43410., 43590., 43680., 43710., 43920., 43980.,
#        44010., 44040., 44220., 44280., 44340., 44400., 44520., 44640.,
#        44670., 44700., 44730., 44970., 45000., 45510., 45540., 45660.,
#        46140., 46230., 46260., 46380., 47070., 47130., 47160., 48150.,
#        48180., 48210., 48300., 48420., 48480., 48540., 48570., 48600.,
#        48630., 48660., 48780., 48990., 49020., 49140., 49200., 50190.,
#        50220., 50370., 50640., 51150., 51240., 51540., 51570., 52110.,
#        52260., 79500.])

# %%
annotations.duration
# Out:
# array([3.063e+04, 1.200e+02, 3.900e+02, 3.000e+01, 3.000e+01, 1.500e+02,
#        3.000e+01, 6.000e+01, 6.000e+01, 3.000e+01, 1.200e+02, 3.000e+01,
#        1.200e+02, 3.000e+01, 6.000e+01, 6.000e+01, 1.200e+02, 3.000e+01,
#        3.000e+01, 1.200e+02, 2.100e+02, 3.000e+01, 6.000e+01, 1.200e+02,
#        3.000e+01, 1.500e+02, 6.000e+01, 3.000e+01, 3.000e+01, 3.000e+01,
#        1.200e+02, 1.500e+02, 3.000e+01, 3.000e+01, 6.000e+01, 3.000e+01,
#        9.000e+01, 1.890e+03, 3.000e+01, 2.100e+02, 6.000e+01, 9.000e+01,
#        1.500e+02, 3.000e+01, 8.700e+02, 1.800e+02, 2.400e+02, 3.000e+01,
#        1.200e+02, 9.000e+01, 3.000e+01, 9.300e+02, 3.000e+01, 3.000e+01,
#        6.000e+01, 3.000e+01, 3.000e+01, 3.000e+01, 3.000e+01, 3.000e+01,
#        3.000e+01, 1.500e+02, 6.000e+01, 9.000e+01, 6.000e+01, 3.000e+01,
#        3.000e+01, 6.000e+01, 6.000e+01, 1.800e+02, 6.000e+01, 3.000e+01,
#        3.000e+01, 2.700e+02, 3.000e+01, 6.000e+01, 3.000e+01, 2.100e+02,
#        3.000e+01, 6.000e+01, 3.000e+01, 1.800e+02, 8.700e+02, 3.000e+01,
#        6.000e+01, 3.000e+01, 1.200e+02, 8.700e+02, 3.000e+01, 3.000e+01,
#        3.000e+01, 3.000e+02, 3.000e+01, 3.900e+02, 3.000e+01, 3.000e+01,
#        3.000e+01, 3.000e+01, 1.800e+02, 9.000e+01, 3.000e+01, 2.100e+02,
#        6.000e+01, 3.000e+01, 3.000e+01, 1.800e+02, 6.000e+01, 6.000e+01,
#        6.000e+01, 1.200e+02, 1.200e+02, 3.000e+01, 3.000e+01, 3.000e+01,
#        2.400e+02, 3.000e+01, 5.100e+02, 3.000e+01, 1.200e+02, 4.800e+02,
#        9.000e+01, 3.000e+01, 1.200e+02, 6.900e+02, 6.000e+01, 3.000e+01,
#        9.900e+02, 3.000e+01, 3.000e+01, 9.000e+01, 1.200e+02, 6.000e+01,
#        6.000e+01, 3.000e+01, 3.000e+01, 3.000e+01, 3.000e+01, 1.200e+02,
#        2.100e+02, 3.000e+01, 1.200e+02, 6.000e+01, 9.900e+02, 3.000e+01,
#        1.500e+02, 2.700e+02, 5.100e+02, 9.000e+01, 3.000e+02, 3.000e+01,
#        5.400e+02, 1.500e+02, 2.724e+04, 6.900e+03])

# %%
annotations.description
# Out:
# array(['Sleep stage W', 'Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3',
#        'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage 3',
#        'Sleep stage 4', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage 3',
#        'Sleep stage 4', 'Sleep stage W', 'Sleep stage 3', 'Sleep stage 2',
#        'Sleep stage 3', 'Sleep stage 4', 'Sleep stage 3', 'Sleep stage 4',
#        'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 2', 'Sleep stage 3',
#        'Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 2',
#        'Sleep stage 3', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4',
#        'Sleep stage 3', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4',
#        'Sleep stage 3', 'Sleep stage 4', 'Sleep stage 1', 'Sleep stage 3',
#        'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 2', 'Sleep stage 3',
#        'Sleep stage R', 'Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3',
#        'Sleep stage 1', 'Sleep stage 2', 'Sleep stage 1', 'Sleep stage 2',
#        'Sleep stage 3', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4',
#        'Sleep stage 3', 'Sleep stage 4', 'Sleep stage 3', 'Sleep stage 4',
#        'Sleep stage 3', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4',
#        'Sleep stage 3', 'Sleep stage 4', 'Sleep stage 3', 'Sleep stage 4',
#        'Sleep stage 3', 'Sleep stage 4', 'Sleep stage 3', 'Sleep stage 4',
#        'Sleep stage 3', 'Sleep stage 4', 'Sleep stage 1', 'Sleep stage 2',
#        'Sleep stage 1', 'Sleep stage 2', 'Sleep stage 1', 'Sleep stage 2',
#        'Sleep stage 1', 'Sleep stage 2', 'Sleep stage R', 'Sleep stage 2',
#        'Sleep stage 1', 'Sleep stage W', 'Sleep stage 1', 'Sleep stage 2',
#        'Sleep stage 1', 'Sleep stage 2', 'Sleep stage 1', 'Sleep stage 2',
#        'Sleep stage 3', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 2',
#        'Sleep stage 3', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4',
#        'Sleep stage 3', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 2',
#        'Sleep stage 4', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage 3',
#        'Sleep stage 4', 'Sleep stage 3', 'Sleep stage 2', 'Sleep stage 3',
#        'Sleep stage 4', 'Sleep stage 2', 'Sleep stage R', 'Sleep stage 1',
#        'Sleep stage R', 'Sleep stage W', 'Sleep stage 1', 'Sleep stage W',
#        'Sleep stage 1', 'Sleep stage W', 'Sleep stage 1', 'Sleep stage 2',
#        'Sleep stage W', 'Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3',
#        'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 2', 'Sleep stage 3',
#        'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 2', 'Sleep stage 3',
#        'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 2', 'Sleep stage 3',
#        'Sleep stage 2', 'Sleep stage 1', 'Sleep stage R', 'Sleep stage W',
#        'Sleep stage 1', 'Sleep stage R', 'Sleep stage W', 'Sleep stage 1',
#        'Sleep stage W', 'Sleep stage 1', 'Sleep stage W', 'Sleep stage 1',
#        'Sleep stage W', 'Sleep stage ?'], dtype='<U13')

# %%
fig, axs = plt.subplots(nrows=3, ncols=1, figsize=(14,6))

fs = 100
N = 7950000

# Axis 1 - EEG
x = np.arange(N) / fs

axs[0].plot(x, eeg_data[0][:N])
axs[0].set_title(eeg_channels[0])
axs[0].set_xlabel('Seconds (s)')
axs[0].set_ylabel('Voltage (uV)')

axs[0].set_xlim(0, N/fs)

# Axis 2 - EEG
x = np.arange(N) / fs

axs[1].plot(x, eeg_data[1][:N])
axs[1].set_title(eeg_channels[1])
axs[1].set_xlabel('Seconds (s)')
axs[1].set_ylabel('Voltage (uV)')

axs[1].set_xlim(0, N/fs)

# Axis 3 - Hypnogram
t_end = N / fs

stage_map = {'Sleep stage W': 0, 'Sleep stage 1': 1, 'Sleep stage 2': 2, 'Sleep stage 3': 3, 'Sleep stage 4': 4, 'Sleep stage R': 5}

x, y = [], []
for o, d, s in zip(annotations.onset, annotations.duration, annotations.description):
    start, end = max(o, 0), min(o + d, t_end)
    stage = stage_map.get(s, np.nan)
    x += [start, end]
    y += [stage, stage]

axs[2].step(x, y, where='post')
axs[2].set_xlim(0, t_end)
axs[2].set_ylim(-0.5, 5.5)
axs[2].set_yticks([0,1,2,3,4,5])
axs[2].set_yticklabels(['W','N1','N2','N3', 'N4', 'R'])
axs[2].set_xlabel('Seconds (s)')
axs[2].set_title('Hypnogram')

plt.tight_layout()

# %% [markdown]
# ### Data Preparation (Single Channel)

# %%
len(psg_files)
# Out:
# 153

# %%
X_data = []
y_data = []
window_length = 3000  

for psg_file, hypnogram_file in zip(psg_files[:50], hypnogram_files[:50]):
    raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
    eeg_channel1 = raw_edf.get_data(picks=['EEG Fpz-Cz'])[0]

    annotations = mne.read_annotations(hypnogram_file)

    stage_map = {'Sleep stage W': 0, 'Sleep stage 1': 1, 'Sleep stage 2': 2, 'Sleep stage 3': 3, 'Sleep stage 4': 4, 'Sleep stage R': 5}

    for i, (onset, duration, description) in enumerate(zip(annotations.onset, annotations.duration, annotations.description)):
        if description not in stage_map:
            continue

        for segment in range(int(onset * fs), int(onset * fs + duration * fs), window_length):
            start_sample = segment
            end_sample = segment + window_length

            if end_sample <= len(eeg_channel1):
                window = eeg_channel1[start_sample:end_sample]

                if len(window) == window_length:
                    X_data.append(window)
                    y_data.append(stage_map[description])


X = np.array(X_data)
y = np.array(y_data)
# Out:
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/317393651.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)

# %%
X.shape
# Out:
# (136394, 3000)

# %%
y.shape
# Out:
# (136394,)

# %%
np.bincount(y)
# Out:
# array([93400,  4269, 22970,  3697,  2382,  9676])

# %%
X = (X - X.mean()) / X.std()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y)

# %%
np.bincount(y_train) / len(y_train)
# Out:
# array([0.68478211, 0.03129726, 0.16840948, 0.02709985, 0.01746781,
#        0.0709435 ])

# %%
np.bincount(y_test) / len(y_test)
# Out:
# array([0.68477583, 0.03130613, 0.16840793, 0.02712709, 0.01744932,
#        0.07093369])

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

X_train = torch.FloatTensor(X_train).unsqueeze(1).to(device)
X_test = torch.FloatTensor(X_test).unsqueeze(1).to(device)
y_train = torch.LongTensor(y_train).to(device)
y_test = torch.LongTensor(y_test).to(device)

# %%
device
# Out:
# device(type='cuda')

# %% [markdown]
# ### Model Training

# %%
model = nn.Sequential(
    nn.Conv1d(1, 32, kernel_size=50, stride=6),
    nn.ReLU(),
    nn.MaxPool1d(8),
    nn.Conv1d(32, 64, kernel_size=8),
    nn.ReLU(),
    nn.MaxPool1d(8),
    nn.Flatten(),
    nn.Linear(64 * 6, 128),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(128, 6)
).to(device)

criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
epochs = 10
batch_size = 64

for epoch in range(epochs):
    model.train()

    total_loss = 0

    for i in range(0, len(X_train), batch_size):
        batch_X = X_train[i:i+batch_size].to(device)
        batch_y = y_train[i:i+batch_size].to(device)

        optimizer.zero_grad()

        outputs = model(batch_X)

        loss = criterion(outputs, batch_y)
        loss.backward()

        optimizer.step()
        total_loss += loss.item()

    print(f'Epoch {epoch+1}/{epochs}, Loss: {total_loss/len(X_train):.4f}')
# Out:
# Epoch 1/10, Loss: 0.0057
# Epoch 2/10, Loss: 0.0041
# Epoch 3/10, Loss: 0.0038
# Epoch 4/10, Loss: 0.0036
# Epoch 5/10, Loss: 0.0035
# Epoch 6/10, Loss: 0.0034
# Epoch 7/10, Loss: 0.0033
# Epoch 8/10, Loss: 0.0032
# Epoch 9/10, Loss: 0.0032
# Epoch 10/10, Loss: 0.0031

# %%
model.eval()

with torch.no_grad():
    predictions = model(X_test)
    predicted_classes = torch.argmax(predictions, dim=1).cpu().numpy()

accuracy = accuracy_score(y_test.cpu().numpy(), predicted_classes)

# %%
accuracy
# Out:
# 0.9222845412221856

# %%
confusion_matrix(y_test.cpu().numpy(), predicted_classes)
# Out:
# array([[18432,   137,    40,     0,     0,    71],
#        [  142,   177,   271,     1,     0,   263],
#        [   50,    36,  4147,    96,     0,   265],
#        [    7,     0,   194,   431,   108,     0],
#        [    5,     0,     2,    84,   385,     0],
#        [   80,    67,   201,     0,     0,  1587]])

# %% [markdown]
# ### Data Preparation (Both Channels)

# %%
len(psg_files)
# Out:
# 153

# %%
X_data = []
y_data = []
window_length = 3000  # 30s

for psg_file, hypnogram_file in zip(psg_files[:50], hypnogram_files[:50]):
    raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
    eeg_channel1 = raw_edf.get_data(picks=['EEG Fpz-Cz'])[0]
    eeg_channel2 = raw_edf.get_data(picks=['EEG Pz-Oz'])[0]

    annotations = mne.read_annotations(hypnogram_file)

    stage_map = {'Sleep stage W': 0, 'Sleep stage 1': 1, 'Sleep stage 2': 2, 'Sleep stage 3': 3, 'Sleep stage 4': 4, 'Sleep stage R': 5}

    for i, (onset, duration, description) in enumerate(zip(annotations.onset, annotations.duration, annotations.description)):
        if description not in stage_map:
            continue

        for segment in range(int(onset * fs), int(onset * fs + duration * fs), window_length):
            start_sample = segment
            end_sample = segment + window_length

            if end_sample <= len(eeg_channel1):
                window1 = eeg_channel1[start_sample:end_sample]
                window2 = eeg_channel2[start_sample:end_sample]

                if len(window1) == window_length:
                    X_data.append(np.stack([window1, window2], axis=0))
                    y_data.append(stage_map[description])


X = np.array(X_data)
y = np.array(y_data)
# Out:
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)
# /tmp/ipykernel_19/1305365252.py:6: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_edf = mne.io.read_raw_edf(psg_file, preload=True, verbose=False)

# %%
X.shape
# Out:
# (136394, 2, 3000)

# %%
y.shape
# Out:
# (136394,)

# %%
np.bincount(y)
# Out:
# array([93400,  4269, 22970,  3697,  2382,  9676])

# %%
X = (X - X.mean()) / X.std()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y)

# %%
np.bincount(y_train) / len(y_train)
# Out:
# array([0.68478211, 0.03129726, 0.16840948, 0.02709985, 0.01746781,
#        0.0709435 ])

# %%
np.bincount(y_test) / len(y_test)
# Out:
# array([0.68477583, 0.03130613, 0.16840793, 0.02712709, 0.01744932,
#        0.07093369])

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

X_train = torch.FloatTensor(X_train).to(device)
X_test = torch.FloatTensor(X_test).to(device)
y_train = torch.LongTensor(y_train).to(device)
y_test = torch.LongTensor(y_test).to(device)

# %%
device
# Out:
# device(type='cuda')

# %% [markdown]
# ### Model Training

# %%
model = nn.Sequential(
    nn.Conv1d(2, 32, kernel_size=50, stride=6),
    nn.ReLU(),
    nn.MaxPool1d(8),
    nn.Conv1d(32, 64, kernel_size=8),
    nn.ReLU(),
    nn.MaxPool1d(8),
    nn.Flatten(),
    nn.Linear(64 * 6, 128),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(128, 6)
).to(device)

criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
epochs = 10
batch_size = 64

for epoch in range(epochs):
    model.train()

    total_loss = 0

    for i in range(0, len(X_train), batch_size):
        batch_X = X_train[i:i+batch_size].to(device)
        batch_y = y_train[i:i+batch_size].to(device)

        optimizer.zero_grad()

        outputs = model(batch_X)

        loss = criterion(outputs, batch_y)
        loss.backward()

        optimizer.step()
        total_loss += loss.item()

    print(f'Epoch {epoch+1}/{epochs}, Loss: {total_loss/len(X_train):.4f}')
# Out:
# Epoch 1/10, Loss: 0.0054
# Epoch 2/10, Loss: 0.0038
# Epoch 3/10, Loss: 0.0035
# Epoch 4/10, Loss: 0.0033
# Epoch 5/10, Loss: 0.0032
# Epoch 6/10, Loss: 0.0031
# Epoch 7/10, Loss: 0.0031
# Epoch 8/10, Loss: 0.0030
# Epoch 9/10, Loss: 0.0030
# Epoch 10/10, Loss: 0.0029

# %%
model.eval()

with torch.no_grad():
    predictions = model(X_test)
    predicted_classes = torch.argmax(predictions, dim=1).cpu().numpy()

accuracy = accuracy_score(y_test.cpu().numpy(), predicted_classes)

# %%
accuracy
# Out:
# 0.9304959859232377

# %%
confusion_matrix(y_test.cpu().numpy(), predicted_classes)
# Out:
# array([[18443,   156,    35,     2,     0,    44],
#        [   95,   256,   253,     1,     0,   249],
#        [   13,    71,  4145,   125,     0,   240],
#        [    5,     0,   151,   519,    65,     0],
#        [    0,     0,     0,   125,   351,     0],
#        [   16,    88,   162,     0,     0,  1669]])
