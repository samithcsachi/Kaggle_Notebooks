# %% [markdown]
# <a href="https://www.kaggle.com/code/samithsachidanandan/image-classification-with-python-and-scikit-learn?scriptVersionId=271543687" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ### Imporiting the necessary Libraries

# %%
import os
import pickle 
from skimage.io import imread 
from skimage.transform import resize
import numpy as np 
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Loading the Data

# %%
input_dir = '/kaggle/input/matchbox-car-parking-occupancy/matchbox_cars_parkinglot'

categories = ['empty', 'occupied']

data = []

labels = []

# %% [markdown]
# ### Preparing the Data

# %%
for category_idx, category  in enumerate(categories):

    for file in os.listdir(os.path.join(input_dir, category)):
        img_path = os.path.join(input_dir, category, file )
        img  = imread(img_path)
        img = resize(img, (15,15)) 
        data.append(img.flatten())
        labels.append (category_idx)

data = np.asarray(data)

labels = np.asarray(labels)

# %% [markdown]
# ### Train Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, shuffle=True, stratify=labels)

# %% [markdown]
# ### Model Training with Grid Search

# %%
classifier = SVC()

parameters = [{'gamma':[0.01,0.001,0.0001], 'C':[1,10,100,1000]}]

grid_search = GridSearchCV(classifier, parameters)

grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid=[{'C': [1, 10, 100, 1000],
#                           'gamma': [0.01, 0.001, 0.0001]}])

# %% [markdown]
# ### Model Performance

# %%
best_estimator = grid_search.best_estimator_

y_prediction = best_estimator.predict(X_test)

score = accuracy_score(y_prediction, y_test)

print('{}% of samples were correctly classified'.format(str(score *100)))
# Out:
# 95.08670520231213% of samples were correctly classified

# %% [markdown]
# ### Saving the Model

# %%
pickle.dump(best_estimator, open('./model.p', 'wb'))

# %%
# !ls /kaggle/working
# Out:
# model.p  __notebook__.ipynb
